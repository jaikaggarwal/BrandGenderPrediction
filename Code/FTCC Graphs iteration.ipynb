# %% [markdown]
# Two main tasks for this notebook.
# 1) Plot brand gender against category usage gender.
# 2) 1d jitter plot of brands against heshe axis
# 3) Get better unstanding of the gender-classifying algorithm.

# %%
import gensim.models.keyedvectors as word2vec
import time
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize
import os
import matplotlib.pyplot as plt
from pylab import *
import scipy
import string

# %%
#Plot brand gender against category
# Step 1: Find relative femaleness of each category (what percent is female in each)
# Step 2: Plot what percentage of TOTAL female brands are found in each category
df = pd.read_csv('ftcc_he_she_category_value_counts.csv', header=None)
df_gloss = pd.read_csv('glossary.csv')
df = df[df[0] != 'BASELINE']
df_sums = df.groupby(0).sum()
df_female = df[df[1] == 'F']
missing = set(df_sums.index.tolist()).difference(set(df_female[0].tolist()))
for item in missing:
    df_female = df_female.append({0: item, 1: 'F', 2: 0}, ignore_index=True)
df_joined = pd.merge(df_sums, df_female, on=0)
df_joined['brand_femaleness'] = df_joined['2_y'] / df_joined['2_x']
df_joined = df_joined.sort_values(by='brand_femaleness')
if df_gloss.shape[0] == df_joined.shape[0]:
   df_joined['category_femaleness'] = df_gloss['category_femaleness']
else:
    print("What in heck")
    
df_joined

# total_female = df_female.sum()[2]
# df_joined['brand_femaleness'] = df_joined['2_y'] / total_female
# df_joined
# Out:
#                                                 key_0  2_x  1  2_y  \
# 36        F259 Pasta & Pasta Dishes General Promotion    2  F    0
# 70                                    V363 Toy Stores    3  F    0
# 29  D439 Mens Shaving Equipment & Supplies General...    8  F    0
# 27     D259 Womens Shaving Supplies General Promotion    1  F    0
# 63                                         H631 Paint   11  F    1
# 72                         V365 Sporting Goods Stores    6  F    1
# 58                           H310 Household Batteries    9  F    2
# 48                    G411 Fishing Tackle & Equipment   39  F    9
# 50              G499 Sporting Goods General Promotion   26  F    8
# 0                      A141 Sportswear & Athleticwear  125  F   41
# 65                          T141 Automotive Batteries    3  F    1
# 60                        H413 Dishwashing Detergents    3  F    1
# 6   B122 Investment Products & Services (Excluding...   83  F   28
# 46                     G323 Casual Dining Restaurants   55  F   19
# 2                                       A321 Sneakers   20  F    7
# 16        B651 Advertising, Marketing & Printing Svcs   70  F   25
# 62                H625 Security & Fire Safety Systems   98  F   35
# 18      B722 Stationery,Greeting Cards&Misc Paper Gds   22  F    8
# 44                            F611 Regular Beer & Ale   60  F   22
# 34                                  F122 Cooking Oils   21  F    8
# 4                                     A430 Sunglasses   20  F    8
# 51      G511 Elec & Video Games & Sftwr (Excl PC&Net)   17  F    7
# 14         B541 Web Design, Domain & Hosting Services   14  F    6
# 32                       D543 Nutritional Supplements  146  F   67
# 8               B225 Internet Service Providers (ISP)   58  F   27
# 19                           B913 Employment Agencies   23  F   11
# 17                B721 Office Furniture & Accessories   27  F   13
# 41                        F413 Cocoa & Milk Additives    6  F    3
# 13               B521 Printers & Printing Accessories   18  F    9
# 10          B322 Religious, Charitable & Humanitarian    8  F    4
# ..                                                ...  ... ..  ...
# 22          D181 Women's Scents, Fragrances, Perfumes    9  F    5
# 67                               T421 Travel Services    7  F    4
# 61             H432 Multipurpose Cleaners (Cleansers)    5  F    3
# 64      T139 Vehicles, Sales & Leasing: Comb Copy&NEC   15  F    9
# 56                              H142 Bedding & Linens   43  F   27
# 38         F313 Ice Cream, Frozen Novelties & Sherbet   41  F   26
# 39                            F343 Cookies & Crackers   32  F   21
# 25  D189 Fragrances, General Promotion/Multi-Categ...    3  F    2
# 24         D183 Men's Scents, Fragrances, Aftershaves    6  F    4
# 37              F280 Peanut Butter & Sandwich Spreads    9  F    6
# 3                                       A411 Handbags   29  F   20
# 11                  B430 Insurance Agencies & Brokers   13  F    9
# 1                           A311 Womens Shoes & Boots   55  F   39
# 66                            T412 Cruise Ship Travel   22  F   16
# 21  D149 Face Makeup, General Promotion/Multi-Cate...    4  F    3
# 54               H111 Dinnerware, Glassware & Pottery   36  F   27
# 33                         F113 Artificial Sweeteners    8  F    6
# 20  D119 Skin Care Products, General Promotion/Mul...   50  F   39
# 40                                        F411 Coffee   14  F   11
# 12                             B511 Desktop Computers   10  F    8
# 31  D529 Cold, Cough, Sinus & Asthma Remdies:Comb ...    5  F    4
# 53                    G613 Cat & Dog Food Combination   13  F   11
# 59          H339 Household Paper Products: Comb & NEC   11  F   10
# 26                        D211 Toothpaste & Whiteners   11  F   10
# 30                                 D511 Pain Remedies   11  F   10
# 28  D269 Deodorants & Antiperspirants General Prom...    1  F    1
# 47                    G324 Coffee & Donut Restaurants    2  F    2
# 69                                  V131 Beauty Shops    3  F    3
# 23           D182 Unisex Scents, Fragrances, Perfumes    1  F    1
# 71                          V364 Hobby & Craft Stores    1  F    1
#
#     brand_femaleness  category_femaleness
# 36          0.000000                 0.60
# 70          0.000000                 0.70
# 29          0.000000                 0.40
# 27          0.000000                 1.00
# 63          0.090909                 0.30
# 72          0.166667                 0.40
# 58          0.222222                 0.15
# 48          0.230769                 0.10
# 50          0.307692                 0.50
# 0           0.328000                 0.50
# 65          0.333333                 0.10
# 60          0.333333                 0.80
# 6           0.337349                 0.20
# 46          0.345455                 0.75
# 2           0.350000                 0.50
# 16          0.357143                 0.50
# 62          0.357143                 0.20
# 18          0.363636                 0.50
# 44          0.366667                 0.10
# 34          0.380952                 0.80
# 4           0.400000                 0.80
# 51          0.411765                 0.20
# 14          0.428571                 0.50
# 32          0.458904                 0.40
# 8           0.465517                 0.30
# 19          0.478261                 0.50
# 17          0.481481                 0.30
# 41          0.500000                 0.80
# 13          0.500000                 0.30
# 10          0.500000                 0.60
# ..               ...                  ...
# 22          0.555556                 1.00
# 67          0.571429                 0.50
# 61          0.600000                 0.70
# 64          0.600000                 0.10
# 56          0.627907                 0.60
# 38          0.634146                 0.50
# 39          0.656250                 0.55
# 25          0.666667                 0.80
# 24          0.666667                 0.30
# 37          0.666667                 0.60
# 3           0.689655                 1.00
# 11          0.692308                 0.20
# 1           0.709091                 1.00
# 66          0.727273                 0.50
# 21          0.750000                 0.90
# 54          0.750000                 0.90
# 33          0.750000                 0.80
# 20          0.780000                 0.80
# 40          0.785714                 0.50
# 12          0.800000                 0.20
# 31          0.800000                 0.50
# 53          0.846154                 0.70
# 59          0.909091                 0.80
# 26          0.909091                 0.55
# 30          0.909091                 0.50
# 28          1.000000                 0.50
# 47          1.000000                 0.50
# 69          1.000000                 0.90
# 23          1.000000                 0.60
# 71          1.000000                 0.70
#
# [73 rows x 6 columns]

# %%
# x = set(df_joined['key_0'].tolist())
# l = []
# for index, row in df_gloss.iterrows():
#     l.append("".join([row['code'],row['category'][1:]]))
# x.difference(l)
df_gloss.shape
# Out:
# (73, 4)

# %%
rcParams['font.family'] = 'sans-serif'
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
x = []
y = []
for index, row in df_joined.iterrows():
    x.append(row['category_femaleness'])
    y.append(row['brand_femaleness'])
    plt.scatter(row['category_femaleness'], row['brand_femaleness'], c='black', s=1000, marker=r"$ {} $".format(row['key_0'][:5])) 
# plt.ylim(-0.01, 0.08)
plt.xlabel('Category Femaleness (%)')
plt.ylabel('Brand Femaleness (%)')
plt.title('Category Femaleness against Brand Femaleness from FastText CommonCrawl Projections')
plt.plot(x, np.poly1d(np.polyfit(x, y, 1))(x))
plt.savefig('ftcc_category_vs_brand_femaleness.png')
plt.show()

# %%
# df_glossary = pd.DataFrame()
# df_glossary['code'] = df_joined['key_0'].apply(lambda x: x[:5])
# df_glossary['category'] = df_joined['key_0'].apply(lambda x: x[4:])
# df_glossary.sort_values(by='code').to_csv('glossary.csv')
print(x)

# %%
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)
print("Slope: {}\nIntercept: {}\nR-value: {}\nP-value: {}\nStd-error: {}".format(slope, intercept, r_value, p_value, std_err))
# Out:
# Slope: 0.2355130726868969
# Intercept: 0.41306092040102566
# R-value: 0.23404815668441542
# P-value: 0.04626493161200035
# Std-error: 0.11610405978125493

# %%
#Plot brand gender against category when brands that are like names are ommitted
# Step 1: Find relative femaleness of each category (what percent is female in each)
# Step 2: Plot what percentage of TOTAL female brands are found in each category
df_nn = pd.read_csv('ftcc_he_she_category_value_counts_no_names.csv', header=None)
df_nn = df_nn[df_nn[0] != 'BASELINE']
df_sums_nn = df_nn.groupby(0).sum()
df_female_nn = df_nn[df_nn[1] == 'F']
missing_nn = set(df_sums_nn.index.tolist()).difference(set(df_female_nn[0].tolist()))
for item in missing_nn:
    df_female_nn = df_female_nn.append({0: item, 1: 'F', 2: 0}, ignore_index=True)
df_joined_nn = pd.merge(df_sums_nn, df_female_nn, on=0)
df_joined_nn['brand_femaleness'] = df_joined_nn['2_y'] / df_joined_nn['2_x']
df_joined_nn = df_joined_nn.sort_values(by='brand_femaleness')
df_joined_nn['key_0'] = df_joined_nn['key_0'].apply(lambda x: x[:5])
df_joined_nn.rename(columns={'key_0': 'code'}, inplace=True)
if df_gloss.shape[0] == df_joined.shape[0]:
   df_joined_nn = pd.merge(df_joined_nn, df_gloss, on='code')
else:
    print("What in heck")
df_joined_nn
# total_female_nn = df_female_nn.sum()[2]
# df_joined_nn['brand_femaleness'] = df_joined_nn['2_y'] / total_female_nn
# df_joined_nn
# Out:
#      code  2_x  1  2_y  brand_femaleness  Unnamed: 0  \
# 0   V365     5  F    0          0.000000          72
# 1   V363     3  F    0          0.000000          70
# 2   T141     2  F    0          0.000000          65
# 3   D439     3  F    0          0.000000          29
# 4   H631     6  F    1          0.166667          63
# 5   G411    24  F    4          0.166667          48
# 6   B722    10  F    2          0.200000          18
# 7   H310     9  F    2          0.222222          58
# 8   F611    36  F    9          0.250000          44
# 9   A430    11  F    3          0.272727           4
# 10  G323    43  F   12          0.279070          46
# 11  A141    75  F   21          0.280000           0
# 12  B122    67  F   20          0.298507           6
# 13  B651    61  F   19          0.311475          16
# 14  H625    75  F   25          0.333333          62
# 15  G511    16  F    6          0.375000          51
# 16  G499    13  F    5          0.384615          50
# 17  B541    14  F    6          0.428571          14
# 18  A321     9  F    4          0.444444           2
# 19  B225    47  F   21          0.446809           8
# 20  F122    13  F    6          0.461538          34
# 21  B721    17  F    8          0.470588          17
# 22  D543   123  F   59          0.479675          32
# 23  B322     8  F    4          0.500000          10
# 24  H413     2  F    1          0.500000          60
# 25  F229     2  F    1          0.500000          35
# 26  G541     2  F    1          0.500000          52
# 27  B521    12  F    6          0.500000          13
# 28  G141    12  F    6          0.500000          45
# 29  D189     2  F    1          0.500000          25
# ..    ...  ... ..  ...               ...         ...
# 39  H432     5  F    3          0.600000          61
# 40  F413     5  F    3          0.600000          41
# 41  F519     5  F    3          0.600000          42
# 42  H122    25  F   15          0.600000          55
# 43  F343    19  F   12          0.631579          39
# 44  H213     6  F    4          0.666667          57
# 45  D181     6  F    4          0.666667          22
# 46  A411    19  F   13          0.684211           3
# 47  H142    32  F   22          0.687500          56
# 48  B430    10  F    7          0.700000          11
# 49  A311    35  F   26          0.742857           1
# 50  T139     8  F    6          0.750000          64
# 51  B511     8  F    6          0.750000          12
# 52  F280     4  F    3          0.750000          37
# 53  D529     4  F    3          0.750000          31
# 54  F313    26  F   20          0.769231          38
# 55  F411     9  F    7          0.777778          40
# 56  T412    14  F   11          0.785714          66
# 57  G613    10  F    8          0.800000          53
# 58  H111    21  F   17          0.809524          54
# 59  D119    40  F   33          0.825000          20
# 60  F113     7  F    6          0.857143          33
# 61  D511     8  F    7          0.875000          30
# 62  H339     7  F    7          1.000000          59
# 63  D211     7  F    7          1.000000          26
# 64  G324     2  F    2          1.000000          47
# 65  D183     4  F    4          1.000000          24
# 66  D149     3  F    3          1.000000          21
# 67  V131     2  F    2          1.000000          69
# 68  V364     1  F    1          1.000000          71
#
#                                              category  category_femaleness
# 0                               Sporting Goods Stores                 0.40
# 1                                          Toy Stores                 0.70
# 2                                Automotive Batteries                 0.10
# 3    Mens Shaving Equipment & Supplies General Pro...                 0.40
# 4                                               Paint                 0.30
# 5                          Fishing Tackle & Equipment                 0.10
# 6            Stationery,Greeting Cards&Misc Paper Gds                 0.50
# 7                                 Household Batteries                 0.15
# 8                                  Regular Beer & Ale                 0.10
# 9                                          Sunglasses                 0.80
# 10                          Casual Dining Restaurants                 0.75
# 11                          Sportswear & Athleticwear                 0.50
# 12   Investment Products & Services (Excluding Ret...                 0.20
# 13             Advertising, Marketing & Printing Svcs                 0.50
# 14                     Security & Fire Safety Systems                 0.20
# 15           Elec & Video Games & Sftwr (Excl PC&Net)                 0.20
# 16                   Sporting Goods General Promotion                 0.50
# 17              Web Design, Domain & Hosting Services                 0.50
# 18                                           Sneakers                 0.50
# 19                   Internet Service Providers (ISP)                 0.30
# 20                                       Cooking Oils                 0.80
# 21                     Office Furniture & Accessories                 0.30
# 22                            Nutritional Supplements                 0.40
# 23               Religious, Charitable & Humanitarian                 0.60
# 24                             Dishwashing Detergents                 0.80
# 25                          Cereals General Promotion                 0.75
# 26                                       Stuffed Toys                 0.60
# 27                    Printers & Printing Accessories                 0.30
# 28                               Cameras (Excl Video)                 0.40
# 29   Fragrances, General Promotion/Multi-Category/...                 0.80
# ..                                                ...                  ...
# 39                  Multipurpose Cleaners (Cleansers)                 0.70
# 40                             Cocoa & Milk Additives                 0.80
# 41                    Candy & Mints General Promotion                 0.50
# 42                           Mattresses & Box Springs                 0.50
# 43                                 Cookies & Crackers                 0.55
# 44                                  Laundry Equipment                 0.90
# 45               Women's Scents, Fragrances, Perfumes                 1.00
# 46                                           Handbags                 1.00
# 47                                   Bedding & Linens                 0.60
# 48                       Insurance Agencies & Brokers                 0.20
# 49                               Womens Shoes & Boots                 1.00
# 50           Vehicles, Sales & Leasing: Comb Copy&NEC                 0.10
# 51                                  Desktop Computers                 0.20
# 52                   Peanut Butter & Sandwich Spreads                 0.60
# 53     Cold, Cough, Sinus & Asthma Remdies:Comb & NEC                 0.50
# 54              Ice Cream, Frozen Novelties & Sherbet                 0.50
# 55                                             Coffee                 0.50
# 56                                 Cruise Ship Travel                 0.50
# 57                         Cat & Dog Food Combination                 0.70
# 58                    Dinnerware, Glassware & Pottery                 0.90
# 59   Skin Care Products, General Promotion/Multi-C...                 0.80
# 60                              Artificial Sweeteners                 0.80
# 61                                      Pain Remedies                 0.50
# 62               Household Paper Products: Comb & NEC                 0.80
# 63                             Toothpaste & Whiteners                 0.55
# 64                         Coffee & Donut Restaurants                 0.50
# 65              Men's Scents, Fragrances, Aftershaves                 0.30
# 66   Face Makeup, General Promotion/Multi-Category...                 0.90
# 67                                       Beauty Shops                 0.90
# 68                               Hobby & Craft Stores                 0.70
#
# [69 rows x 8 columns]

# %%
plt.clf()
rcParams['font.family'] = 'sans-serif'
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
x_nn = []
y_nn = []
for index, row in df_joined_nn.iterrows():
    x_nn.append(row['category_femaleness'])
    y_nn.append(row['brand_femaleness'])
    plt.scatter(row['category_femaleness'], row['brand_femaleness'], c='black', s=1000, marker=r"$ {} $".format(row['code'][:5])) 
#plt.ylim(-0.01, 0.08)
plt.xlabel('Category Femaleness (%)')
plt.ylabel('Brand Femaleness (%)')
plt.title('Category Femaleness against Brand Femaleness from FastText Common Crawl Projections, Name-Like Brands Excluded')
plt.plot(x_nn, np.poly1d(np.polyfit(x_nn, y_nn, 1))(x_nn))
plt.savefig('ftcc_category_vs_brand_femaleness_no_names.png')
plt.show()

# %%
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x_nn, y_nn)
print("Slope: {}\nIntercept: {}\nR-value: {}\nP-value: {}\nStd-error: {}".format(slope, intercept, r_value, p_value, std_err))
# Out:
# Slope: 0.4160557837221912
# Intercept: 0.33658991090762785
# R-value: 0.39116364926934344
# P-value: 0.0008893643368092279
# Std-error: 0.11959005644021904
