# %%
import sys
import time
import requests
from datetime import datetime, timedelta
import json
import numpy as np
from sentence_transformers import SentenceTransformer
import pandas as pd
import statsmodels.api as sm
import gensim.models.keyedvectors as word2vec
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize
from scipy.stats import pearsonr
import re

# %%
CLEANED_NAMES_FILE = "../Data/category_cleaned_names.csv"

# %% [markdown]
# # Initialize Model

# %%
w2v_model = word2vec.KeyedVectors.load_word2vec_format('../Data/GoogleNews-vectors-negative300.bin', binary=True)
w2v_vocab = [key.lower() for key in w2v_model.vocab.keys()]
# Out:
# I0525 12:09:45.862390  8912 utils_any2vec.py:341] loading projection weights from ../Data/GoogleNews-vectors-negative300.bin
# W0525 12:09:45.883334  8912 smart_open_lib.py:385] this function is deprecated, use smart_open.open instead
# I0525 12:11:02.130850  8912 utils_any2vec.py:405] loaded (3000000, 300) matrix from ../Data/GoogleNews-vectors-negative300.bin

# %% [markdown]
# # Initialize She-He Axis

# %%
she_vec = w2v_model.get_vector('she')
he_vec = w2v_model.get_vector('he')
# she_vec = normalize(she_vec.reshape(1, -1))
# he_vec = normalize(he_vec.reshape(1, -1))
# he_she_axis = np.subtract(she_vec, he_vec)
she_vec = she_vec.reshape(1, -1)
he_vec = he_vec.reshape(1, -1)
he_she_axis = normalize(np.subtract(she_vec, he_vec))

# %%
cosine_similarity(she_vec, he_vec)
# Out:
# array([[0.612995]], dtype=float32)

# %% [markdown]
# # Get brands without duplicates

# %%
df_brands = pd.read_csv('../Data/brand_names_coded.csv')
df_brands_no_dup = df_brands.drop_duplicates(subset='BRAND')
all_brands = df_brands['BRAND'].tolist()
no_dup = df_brands_no_dup['BRAND'].tolist()
print("LEN ALL BRANDS", len(all_brands))
print("LEN ALL BRANDS NO DUPLICATED", len(no_dup))

# df_brands = df_brands[df_brands['BRAND'].isin(model_vocab)]
# print(df_brands.shape)
# df_brands['ALIGNMENT'] = df_brands['BRAND'].apply(lambda x: get_simple_alignment(x, he_she_axis))
# df_brands = df_brands.reset_index()
# df_brands = df_brands[['BRAND', 'CATEGORY', 'ALIGNMENT']]
# Out:
# LEN ALL BRANDS 2458
# LEN ALL BRANDS NO DUPLICATED 2308

# %%
len(set(df_brands_no_dup['CATEGORY'].tolist()))
# Out:
# 74

# %%
vecs = []
count = 0
valid_brands = []
for brand in no_dup:
    try:
        word_vec = w2v_model.get_vector(brand.capitalize())
        vecs.append(word_vec)
        count +=1
        valid_brands.append(brand)
    except KeyError:
        try:
            index = w2v_vocab.index(brand.lower())
        except ValueError:
            continue
        word_vec = w2v_model.get_vector(w2v_model.index2entity[index])
        vecs.append(word_vec)
        valid_brands.append(brand)
print("TOTAL NUMBER OF VECTORS", len(vecs))
print("TOTAL WITH CAPITALS", count)
# Out:
# TOTAL NUMBER OF VECTORS 1471
# TOTAL WITH CAPITALS 1298

# %%
def get_simple_alignment(vectors, gender_subspace):
    vectors=normalize(vectors)
    print(vectors.shape)
    print(gender_subspace.shape)
    gen_comp = np.dot(vectors, gender_subspace)
#     if gen_comp < 0:
#         return 'M'
#     else:
#         return 'F'
    return gen_comp

# %%
alignment = get_simple_alignment(vecs, he_she_axis[0])
# Out:
# (1471, 300)
# (300,)

# %%
v = normalize([[1, 0, 1], [5, 4, 3]])
np.dot(v[1], v[1])
# Out:
# 0.9999999999999998

# %%
df_alignment = pd.DataFrame({'brand': valid_brands, 'alignment': alignment})
df_alignment = df_alignment.sort_values(by='alignment')
df_alignment.to_csv('../Data/alignment_scores.csv')

# %% [markdown]
# # Correlation of normalized and unnormalized gender subspace results

# %%
she_vec_unnorm = normalize(she_vec.reshape(1, -1))
he_vec_unnorm = normalize(he_vec.reshape(1, -1))
he_she_axis_unnorm = np.subtract(she_vec_unnorm, he_vec_unnorm)
she_vec = she_vec.reshape(1, -1)
he_vec = he_vec.reshape(1, -1)
he_she_axis = normalize(np.subtract(she_vec, he_vec))

# %%
alignment_unnorm = get_simple_alignment(vecs, he_she_axis_unnorm[0])
alignment = get_simple_alignment(vecs, he_she_axis[0])
pearsonr(alignment_unnorm, alignment)
# Out:
# (1471, 300)
# (300,)
# (1471, 300)
# (300,)
# (0.9812711299009028, 0.0)

# %% [markdown]
# # Category Embeddings

# %%
def preprocess(category):
    category = category[5:]
    category = re.sub(",|'s|& |/", ' ', category)
    category = re.sub("  ", " ", category )
    return category.lower()

# %%
def get_brand_categories(brands, concise=False):
    if concise:
        cleaned_name_map = pd.read_csv(CLEANED_NAMES_FILE).set_index('Original').to_dict()['Concise']
    else:
        cleaned_name_map = pd.read_csv(CLEANED_NAMES_FILE).set_index('Original').to_dict()['Corrected']
    valid_df = df_brands_no_dup[df_brands_no_dup['BRAND'].isin(brands)]
    brand_category_mapping = valid_df.set_index('BRAND').to_dict()['CATEGORY']
    brand_category_cleaned = {brand: preprocess(cleaned_name_map[category]) for brand, category in brand_category_mapping.items()}
#     brand_category_mapping = {brand: preprocess(category) for brand, category in brand_category_cleaned.items()}
    return brand_category_cleaned, set(brand_category_cleaned.values())

# %%
def get_category_vectors(category):
    words = category.split(" ")
    cat_vecs = np.array([])
    for word in words:
        if word != '':
            index = w2v_vocab.index(word)
            word_vec = w2v_model.get_vector(w2v_model.index2entity[index])
            if cat_vecs.shape[0] == 0:
                cat_vecs = word_vec
            else:
                cat_vecs = np.vstack([cat_vecs, word_vec])
        else:
            print(category)
            print("IT SLIPPED THROUGH")
#     print(np.mean(cat_vecs, axis=0).shape)
#     print(cat_vecs)
    cat_vecs = cat_vecs.reshape(-1, 300)
    return np.mean(cat_vecs, axis=0)

# %% [markdown]
# # Project Categories onto Gender Subspace

# %%
def get_category_projections(valid_brands, concise=False):
    brand_category_mapping, categories = get_brand_categories(valid_brands, concise)
    categories = list(categories)
    category_vec_map = {}
    category_vectors = np.array([])
    
    for category in categories:
        new_vec = get_category_vectors(category)
        category_vec_map[category] = new_vec
        if category_vectors.shape[0] == 0:
            category_vectors = category_vec_map[category]
        else:
            new_vec = category_vec_map[category].reshape(1, -1)
            category_vectors = np.vstack([category_vectors, new_vec])
    
    category_alignment = get_simple_alignment(category_vectors, he_she_axis[0])
    cat_al = pd.DataFrame({'category': list(categories), 'alignment': list(map(np.round, category_alignment, [3]*len(category_alignment)))})
    cat_al['gender'] = cat_al['alignment'].apply(lambda x: 'F' if x >=0 else 'M')
    cat_al.sort_values(by='category').to_csv('../Data/word2vec_category_alignment.csv')
    print("TOTAL NUMBER OF VECTORS", len(category_vectors))
    print("LENGTH OF ALIGNMENT", len(alignment[alignment>0]))
    print("LENGTH OF RESIDUAL ALIGNMENT", len(category_alignment[category_alignment>0]))
    print(len(category_alignment))
    print(len(alignment[alignment>0])/len(alignment))
    print(len(category_alignment[category_alignment>0])/len(category_alignment))
    return category_vectors, categories
    
    
    
category_vectors, categories = get_category_projections(valid_brands, False)
# Out:
# (72, 300)
# (300,)
# TOTAL NUMBER OF VECTORS 72
# LENGTH OF ALIGNMENT 1089
# LENGTH OF RESIDUAL ALIGNMENT 63
# 72
# 0.7403127124405167
# 0.875

# %% [markdown]
# # Intuition Test to Ensure Similarity

# %%
def get_k_most_similar(cat_vecs, categories, index, k):
    categories = np.array(categories)
    query = categories[index]
    query_vector = cat_vecs[index]
    print('CATEGORY: ',  query)
    all_sims = cosine_similarity(cat_vecs, query_vector.reshape(1, -1))
    mask = np.argsort(all_sims, axis=0)[-k-1:-1][::-1]
    print(categories[mask.flatten()])
    return categories[mask.flatten()], all_sims[mask].flatten()

cat_index = np.array([])
sim_index = np.array([])
sim_values = np.array([])
k = 3
for i in range(len(categories)):
    k_closest_cats, k_closest_sims = get_k_most_similar(category_vectors, categories, i, k)
    cat_index = np.append(cat_index, np.repeat(categories[i], k))
    sim_index = np.append(sim_index, k_closest_cats)
    sim_values = np.append(sim_values, k_closest_sims)
# Out:
# CATEGORY:  sunglasses
# ['sneakers' 'women shoes boots' 'handbags']
# CATEGORY:  women shaving supplies
# ['mens shaving equipment supplies' 'deodorants antiperspirants'
#  'skin care products']
# CATEGORY:  religious charitable humanitarian
# ['sporting goods' 'women shaving supplies' 'employment agencies']
# CATEGORY:  employment agencies
# ['insurance agencies brokers' 'investment products services'
#  'internet service providers']
# CATEGORY:  face makeup
# ['paint' 'skin care products' 'sunglasses']
# CATEGORY:  artificial sweeteners
# ['cocoa milk additives' 'ice cream frozen novelties sherbet'
#  'nutritional supplements']
# CATEGORY:  cooking oils
# ['pasta pasta dishes' 'dishwashing detergents' 'cocoa milk additives']
# CATEGORY:  credit cards
# ['loan credit products services'
#  'stationery greeting cards miscellaneous paper goods'
#  'household paper products']
# CATEGORY:  electronic video games software
# ['desktop computers' 'cable television providers systems'
#  'web design domain hosting services']
# CATEGORY:  sporting goods stores
# ['sporting goods' 'toy stores' 'beauty shops']
# CATEGORY:  casual dining restaurants
# ['coffee donut restaurants' 'pasta pasta dishes' 'sporting goods stores']
# CATEGORY:  tv networks stations production companies
# ['cable television providers systems' 'internet service providers'
#  'investment products services']
# CATEGORY:  bedding linens
# ['office furniture accessories' 'dinnerware glassware pottery'
#  'laundry equipment']
# CATEGORY:  toy stores
# ['sporting goods stores' 'stuffed toys' 'office furniture accessories']
# CATEGORY:  cat dog food
# ['coffee donut restaurants' 'stuffed toys' 'chips nuts popcorn pretzels']
# CATEGORY:  women scents fragrances perfumes
# ['unisex scents fragrances perfumes' 'men scents fragrances aftershaves'
#  'fragrances']
# CATEGORY:  cereals
# ['cocoa milk additives' 'nutritional supplements' 'cookies crackers']
# CATEGORY:  pasta pasta dishes
# ['cooking oils' 'peanut butter sandwich spreads'
#  'coffee donut restaurants']
# CATEGORY:  mens shaving equipment supplies
# ['women shaving supplies' 'laundry equipment'
#  'office furniture accessories']
# CATEGORY:  web design domain hosting services
# ['internet service providers' 'advertising marketing printing services'
#  'investment products services']
# CATEGORY:  women shoes boots
# ['sneakers' 'sportswear athleticwear' 'handbags']
# CATEGORY:  beer ale
# ['coffee donut restaurants' 'coffee' 'ice cream frozen novelties sherbet']
# CATEGORY:  travel services
# ['investment products services' 'cruise ship travel'
#  'internet service providers']
# CATEGORY:  fragrances
# ['unisex scents fragrances perfumes' 'women scents fragrances perfumes'
#  'men scents fragrances aftershaves']
# CATEGORY:  sportswear athleticwear
# ['handbags' 'women shoes boots' 'unisex scents fragrances perfumes']
# CATEGORY:  dinnerware glassware pottery
# ['bedding linens' 'office furniture accessories' 'pasta pasta dishes']
# CATEGORY:  internet service providers
# ['cable television providers systems' 'web design domain hosting services'
#  'investment products services']
# CATEGORY:  dishwashing detergents
# ['toothpaste whiteners' 'deodorants antiperspirants' 'cooking oils']
# CATEGORY:  paint
# ['face makeup' 'toothpaste whiteners' 'dinnerware glassware pottery']
# CATEGORY:  pain remedies
# ['cold cough sinus asthma remedies' 'skin care products'
#  'nutritional supplements']
# CATEGORY:  insurance agencies brokers
# ['employment agencies' 'internet service providers'
#  'loan credit products services']
# CATEGORY:  handbags
# ['sportswear athleticwear' 'unisex scents fragrances perfumes'
#  'women scents fragrances perfumes']
# CATEGORY:  coffee
# ['coffee donut restaurants' 'beer ale' 'cocoa milk additives']
# CATEGORY:  cookies crackers
# ['chips nuts popcorn pretzels' 'candy mints'
#  'ice cream frozen novelties sherbet']
# CATEGORY:  coffee donut restaurants
# ['coffee' 'casual dining restaurants' 'peanut butter sandwich spreads']
# CATEGORY:  sporting goods
# ['sporting goods stores'
#  'stationery greeting cards miscellaneous paper goods'
#  'sportswear athleticwear']
# CATEGORY:  cable television providers systems
# ['tv networks stations production companies' 'internet service providers'
#  'electronic video games software']
# CATEGORY:  men scents fragrances aftershaves
# ['women scents fragrances perfumes' 'unisex scents fragrances perfumes'
#  'fragrances']
# CATEGORY:  printers printing accessories
# ['advertising marketing printing services' 'office furniture accessories'
#  'stationery greeting cards miscellaneous paper goods']
# CATEGORY:  investment products services
# ['loan credit products services' 'advertising marketing printing services'
#  'skin care products']
# CATEGORY:  amusement water theme parks
# ['beauty shops' 'casual dining restaurants' 'cat dog food']
# CATEGORY:  cameras
# ['sunglasses' 'electronic video games software'
#  'cable television providers systems']
# CATEGORY:  automotive batteries
# ['household batteries' 'vehicles sales leasing'
#  'office furniture accessories']
# CATEGORY:  household batteries
# ['automotive batteries' 'household paper products'
#  'dishwashing detergents']
# CATEGORY:  vehicles sales leasing
# ['investment products services' 'loan credit products services'
#  'advertising marketing printing services']
# CATEGORY:  stuffed toys
# ['toy stores' 'stationery greeting cards miscellaneous paper goods'
#  'candy mints']
# CATEGORY:  loan credit products services
# ['investment products services' 'credit cards' 'skin care products']
# CATEGORY:  peanut butter sandwich spreads
# ['chips nuts popcorn pretzels' 'coffee donut restaurants'
#  'ice cream frozen novelties sherbet']
# CATEGORY:  unisex scents fragrances perfumes
# ['women scents fragrances perfumes' 'men scents fragrances aftershaves'
#  'fragrances']
# CATEGORY:  chips nuts popcorn pretzels
# ['cookies crackers' 'peanut butter sandwich spreads' 'candy mints']
# CATEGORY:  multipurpose cleaners
# ['dishwashing detergents' 'laundry equipment'
#  'printers printing accessories']
# CATEGORY:  cocoa milk additives
# ['cereals' 'nutritional supplements' 'toothpaste whiteners']
# CATEGORY:  security fire safety systems
# ['cable television providers systems' 'investment products services'
#  'web design domain hosting services']
# CATEGORY:  advertising marketing printing services
# ['printers printing accessories' 'investment products services'
#  'web design domain hosting services']
# CATEGORY:  cruise ship travel
# ['travel services' 'vehicles sales leasing' 'fishing tackle equipment']
# CATEGORY:  office furniture accessories
# ['printers printing accessories' 'bedding linens'
#  'dinnerware glassware pottery']
# CATEGORY:  candy mints
# ['chips nuts popcorn pretzels' 'cookies crackers'
#  'coffee donut restaurants']
# CATEGORY:  snow skis boards blades accessories
# ['mens shaving equipment supplies' 'women shoes boots'
#  'office furniture accessories']
# CATEGORY:  stationery greeting cards miscellaneous paper goods
# ['household paper products' 'printers printing accessories'
#  'sporting goods']
# CATEGORY:  mattresses box springs
# ['bedding linens' 'office furniture accessories' 'stuffed toys']
# CATEGORY:  desktop computers
# ['electronic video games software' 'printers printing accessories'
#  'web design domain hosting services']
# CATEGORY:  cold cough sinus asthma remedies
# ['pain remedies' 'skin care products' 'toothpaste whiteners']
# CATEGORY:  household paper products
# ['household batteries'
#  'stationery greeting cards miscellaneous paper goods'
#  'investment products services']
# CATEGORY:  nutritional supplements
# ['cocoa milk additives' 'cereals' 'skin care products']
# CATEGORY:  deodorants antiperspirants
# ['toothpaste whiteners' 'men scents fragrances aftershaves'
#  'dishwashing detergents']
# CATEGORY:  beauty shops
# ['sporting goods stores' 'toy stores' 'unisex scents fragrances perfumes']
# CATEGORY:  ice cream frozen novelties sherbet
# ['peanut butter sandwich spreads' 'chips nuts popcorn pretzels'
#  'cookies crackers']
# CATEGORY:  laundry equipment
# ['mens shaving equipment supplies' 'bedding linens'
#  'fishing tackle equipment']
# CATEGORY:  skin care products
# ['investment products services' 'toothpaste whiteners'
#  'household paper products']
# CATEGORY:  toothpaste whiteners
# ['deodorants antiperspirants' 'dishwashing detergents'
#  'skin care products']
# CATEGORY:  fishing tackle equipment
# ['laundry equipment' 'mens shaving equipment supplies'
#  'snow skis boards blades accessories']
# CATEGORY:  sneakers
# ['women shoes boots' 'sunglasses' 'sportswear athleticwear']

# %%
df_cat_sim = pd.DataFrame(sim_values, index=[cat_index, sim_index])
df_cat_sim.to_csv("../Data/category_similarities.csv")

# %% [markdown]
# # Subtract Category Embeddings from Brands and Repeat Gender Analysis

# %%
def main(concise=False):
    brand_category_mapping, categories = get_brand_categories(valid_brands, concise)
    categories = list(categories)
    category_vec_map = {}
    for category in categories:
        new_vec = get_category_vectors(category)
        category_vec_map[category] = new_vec

    residual_vecs = []
    residual_count = 0
    residual_valid_brands = []
    for brand in no_dup:
        try:
            residual_word_vec = w2v_model.get_vector(brand.capitalize())
            residual_word_vec = np.subtract(residual_word_vec, category_vec_map[brand_category_mapping[brand]])
            residual_vecs.append(residual_word_vec)
            residual_count +=1
            residual_valid_brands.append(brand)
        except KeyError:
            try:
                residual_index = w2v_vocab.index(brand.lower())
            except ValueError:
                continue
            residual_word_vec = w2v_model.get_vector(w2v_model.index2entity[residual_index])
            residual_word_vec = np.subtract(residual_word_vec, category_vec_map[brand_category_mapping[brand]])
            residual_vecs.append(residual_word_vec)
            residual_valid_brands.append(brand)
    residual_alignment = get_simple_alignment(residual_vecs, he_she_axis[0])
    print("TOTAL NUMBER OF VECTORS", len(residual_vecs))
    print("TOTAL WITH CAPITALS", residual_count)
    print("LENGTH OF ALIGNMENT", len(alignment[alignment>0]))
    print("LENGTH OF RESIDUAL ALIGNMENT", len(residual_alignment[residual_alignment>0]))
    print(len(residual_alignment))
    print(len(alignment[alignment>0])/len(alignment))
    print(len(residual_alignment[residual_alignment>0])/len(residual_alignment))
    residual_df_alignment = pd.DataFrame({'brand': residual_valid_brands, 'residual_alignment': residual_alignment, 'alignment': alignment})
    residual_df_alignment = residual_df_alignment.sort_values(by='residual_alignment')
    residual_df_alignment.to_csv('../Data/residual_alignment_scores.csv')

# %%
main()
# Out:
# TOTAL NUMBER OF VECTORS 1471
# TOTAL WITH CAPITALS 1298
# LENGTH OF ALIGNMENT 1089
# LENGTH OF RESIDUAL ALIGNMENT 683
# 1471
# 0.7403127124405167
# 0.46430999320190347

# %%
main(True)
# Out:
# TOTAL NUMBER OF VECTORS 1471
# TOTAL WITH CAPITALS 1298
# LENGTH OF ALIGNMENT 1089
# LENGTH OF RESIDUAL ALIGNMENT 729
# 1471
# 0.7403127124405167
# 0.495581237253569

# %%
residual_alignment = get_simple_alignment(residual_vecs, he_she_axis[0])
residual_df_alignment = pd.DataFrame({'brand': residual_valid_brands, 'alignment': alignment, 'residual_alignment': residual_alignment})
residual_df_alignment = residual_df_alignment.sort_values(by='residual_alignment')
residual_df_alignment.to_csv('../Data/residual_alignment_scores.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-b06bf889cbe6> in <module>()
# ----> 1 residual_alignment = get_simple_alignment(residual_vecs, he_she_axis[0])
#       2 residual_df_alignment = pd.DataFrame({'brand': residual_valid_brands, 'alignment': alignment, 'residual_alignment': residual_alignment})
#       3 residual_df_alignment = residual_df_alignment.sort_values(by='residual_alignment')
#       4 residual_df_alignment.to_csv('../Data/residual_alignment_scores.csv')
#
# NameError: name 'residual_vecs' is not defined

# %%
print("LENGTH OF ALIGNMENT", len(alignment[alignment>0]))
print("LENGTH OF RESIDUAL ALIGNMENT", len(residual_alignment[residual_alignment>0]))
print(len(residual_alignment))
print(len(alignment[alignment>0])/len(alignment))
print(len(residual_alignment[residual_alignment>0])/len(residual_alignment))

# %%
x = df_brands_no_dup[df_brands_no_dup['BRAND'].isin(valid_brands)]
y = x.set_index('BRAND').to_dict()['CATEGORY']
x.drop_duplicates(subset='CATEGORY')['CATEGORY']

# %%
a = np.mean([w2v_model.get_vector("toy"), w2v_model.get_vector("stores")], axis=0)
b = w2v_model.get_vector(w2v_model.index2entity[w2v_vocab.index("toy_store")])
cosine_similarity(a.reshape(1, -1), b.reshape(1, -1))
# Out:
# array([[0.54730767]], dtype=float32)

# %%
def get_poss(start, i):
    return [word for word in w2v_vocab if word.startswith(start) and i in word]

pairs = [
    ["host", "prov"]

        ]
for pair in pairs:
    print(get_poss(pair[0], pair[1]))
# Out:
# ['hosting_provider', 'hosting_providers', 'hosting_service_providers', 'hostname_provider']

# %%
list(map(np.round, alignment, [3]*len(alignment)))
# Out:
# [-0.076,
#  0.068,
#  -0.004,
#  0.091,
#  -0.027,
#  0.07,
#  0.058,
#  0.017,
#  0.05,
#  0.036,
#  0.073,
#  -0.031,
#  -0.042,
#  0.183,
#  -0.019,
#  0.074,
#  0.068,
#  -0.007,
#  -0.095,
#  0.031,
#  0.015,
#  0.031,
#  0.09,
#  -0.013,
#  -0.06,
#  -0.077,
#  0.201,
#  -0.079,
#  0.131,
#  -0.071,
#  0.044,
#  -0.1,
#  -0.042,
#  0.016,
#  0.054,
#  -0.118,
#  0.012,
#  0.287,
#  0.017,
#  -0.074,
#  -0.097,
#  0.032,
#  0.026,
#  -0.016,
#  0.062,
#  0.099,
#  -0.037,
#  -0.012,
#  0.051,
#  0.023,
#  0.173,
#  -0.053,
#  0.016,
#  0.033,
#  -0.009,
#  0.076,
#  -0.021,
#  0.029,
#  0.076,
#  0.049,
#  0.132,
#  -0.071,
#  0.066,
#  0.094,
#  0.015,
#  0.129,
#  0.114,
#  0.066,
#  0.028,
#  0.012,
#  0.085,
#  0.114,
#  -0.011,
#  -0.049,
#  0.111,
#  0.013,
#  0.082,
#  0.026,
#  0.019,
#  0.135,
#  0.065,
#  0.085,
#  -0.005,
#  0.024,
#  -0.031,
#  0.089,
#  -0.057,
#  -0.019,
#  -0.014,
#  0.108,
#  0.088,
#  0.035,
#  0.08,
#  0.046,
#  0.191,
#  0.146,
#  -0.052,
#  -0.074,
#  0.263,
#  0.025,
#  0.089,
#  0.272,
#  0.095,
#  -0.047,
#  -0.059,
#  0.083,
#  -0.014,
#  -0.043,
#  0.157,
#  0.073,
#  0.314,
#  0.037,
#  0.044,
#  0.147,
#  0.046,
#  0.062,
#  0.133,
#  0.002,
#  0.129,
#  -0.002,
#  0.065,
#  -0.002,
#  0.389,
#  0.103,
#  0.065,
#  0.009,
#  0.191,
#  0.195,
#  0.152,
#  0.268,
#  0.112,
#  -0.067,
#  0.136,
#  0.123,
#  0.012,
#  0.129,
#  0.066,
#  -0.027,
#  -0.096,
#  -0.015,
#  0.395,
#  0.169,
#  0.361,
#  -0.002,
#  0.03,
#  0.066,
#  -0.12,
#  0.138,
#  0.052,
#  0.086,
#  -0.048,
#  0.101,
#  0.015,
#  0.126,
#  0.006,
#  0.001,
#  -0.005,
#  -0.078,
#  0.078,
#  -0.156,
#  -0.044,
#  -0.006,
#  -0.0,
#  0.088,
#  -0.031,
#  0.08,
#  0.075,
#  0.271,
#  0.072,
#  -0.073,
#  0.061,
#  0.17,
#  0.106,
#  0.244,
#  0.087,
#  0.174,
#  0.349,
#  -0.068,
#  0.291,
#  0.154,
#  0.094,
#  0.152,
#  0.083,
#  0.189,
#  0.026,
#  0.317,
#  0.177,
#  0.079,
#  0.133,
#  0.059,
#  0.194,
#  -0.034,
#  0.168,
#  -0.062,
#  0.171,
#  -0.023,
#  0.32,
#  0.03,
#  0.094,
#  -0.039,
#  0.408,
#  0.117,
#  -0.024,
#  -0.03,
#  0.085,
#  0.086,
#  -0.015,
#  -0.056,
#  0.019,
#  -0.031,
#  -0.066,
#  0.105,
#  0.301,
#  0.036,
#  0.022,
#  0.019,
#  0.073,
#  0.073,
#  0.103,
#  0.002,
#  0.018,
#  0.152,
#  0.001,
#  0.007,
#  0.063,
#  0.037,
#  0.101,
#  0.035,
#  0.165,
#  0.021,
#  -0.043,
#  0.024,
#  0.133,
#  0.084,
#  -0.04,
#  0.102,
#  0.081,
#  0.09,
#  -0.05,
#  0.044,
#  0.046,
#  0.012,
#  0.112,
#  0.02,
#  0.064,
#  0.002,
#  0.006,
#  -0.043,
#  0.049,
#  -0.077,
#  -0.041,
#  -0.001,
#  0.071,
#  0.088,
#  0.007,
#  -0.053,
#  0.002,
#  0.047,
#  0.111,
#  -0.052,
#  -0.088,
#  0.046,
#  -0.021,
#  0.004,
#  0.02,
#  -0.013,
#  0.019,
#  -0.09,
#  0.047,
#  0.024,
#  0.094,
#  0.111,
#  -0.04,
#  -0.04,
#  0.066,
#  -0.074,
#  0.196,
#  0.083,
#  0.013,
#  0.02,
#  0.08,
#  -0.001,
#  0.077,
#  0.119,
#  0.082,
#  0.059,
#  -0.011,
#  -0.011,
#  -0.059,
#  -0.02,
#  -0.014,
#  0.04,
#  -0.02,
#  0.086,
#  -0.025,
#  -0.027,
#  0.007,
#  -0.086,
#  0.027,
#  0.103,
#  0.001,
#  -0.043,
#  -0.047,
#  0.051,
#  0.006,
#  0.086,
#  -0.042,
#  0.095,
#  0.011,
#  0.079,
#  0.0,
#  0.089,
#  -0.006,
#  0.003,
#  -0.012,
#  -0.021,
#  -0.001,
#  -0.081,
#  0.119,
#  0.012,
#  0.037,
#  0.064,
#  0.032,
#  0.102,
#  0.195,
#  0.065,
#  0.097,
#  0.04,
#  -0.013,
#  0.047,
#  -0.02,
#  -0.054,
#  -0.08,
#  -0.175,
#  0.137,
#  -0.06,
#  -0.053,
#  0.075,
#  -0.042,
#  0.164,
#  -0.08,
#  0.013,
#  0.091,
#  0.013,
#  -0.039,
#  0.004,
#  0.095,
#  0.048,
#  0.037,
#  -0.113,
#  -0.072,
#  0.01,
#  0.055,
#  0.004,
#  0.04,
#  -0.017,
#  -0.04,
#  0.142,
#  0.053,
#  0.02,
#  -0.006,
#  0.019,
#  -0.023,
#  0.056,
#  0.018,
#  0.034,
#  -0.045,
#  -0.008,
#  0.045,
#  0.087,
#  -0.006,
#  -0.03,
#  0.041,
#  -0.04,
#  0.063,
#  -0.013,
#  0.09,
#  -0.05,
#  0.018,
#  0.026,
#  0.037,
#  -0.029,
#  -0.02,
#  0.13,
#  -0.017,
#  0.048,
#  -0.023,
#  -0.06,
#  0.037,
#  -0.037,
#  -0.025,
#  0.018,
#  0.043,
#  0.078,
#  -0.01,
#  0.043,
#  -0.034,
#  0.027,
#  0.065,
#  0.047,
#  0.037,
#  0.034,
#  0.043,
#  0.019,
#  0.03,
#  -0.04,
#  0.055,
#  0.012,
#  0.048,
#  0.088,
#  -0.007,
#  0.024,
#  -0.021,
#  -0.013,
#  -0.025,
#  -0.002,
#  0.011,
#  0.081,
#  0.022,
#  0.095,
#  0.075,
#  0.06,
#  0.118,
#  0.074,
#  0.058,
#  0.044,
#  0.08,
#  0.043,
#  0.047,
#  0.016,
#  0.024,
#  0.1,
#  -0.013,
#  0.031,
#  0.058,
#  0.028,
#  0.054,
#  -0.01,
#  -0.002,
#  -0.03,
#  -0.059,
#  0.012,
#  -0.035,
#  -0.022,
#  0.011,
#  0.038,
#  -0.029,
#  0.1,
#  0.04,
#  0.091,
#  0.048,
#  0.043,
#  -0.011,
#  0.02,
#  0.021,
#  -0.006,
#  0.172,
#  0.059,
#  0.092,
#  0.082,
#  0.029,
#  -0.003,
#  0.015,
#  0.026,
#  -0.021,
#  -0.07,
#  0.013,
#  0.076,
#  0.002,
#  -0.071,
#  0.1,
#  -0.024,
#  0.061,
#  -0.009,
#  0.009,
#  0.016,
#  0.012,
#  0.184,
#  0.044,
#  0.074,
#  0.18,
#  0.095,
#  0.185,
#  0.002,
#  0.05,
#  0.058,
#  0.024,
#  -0.072,
#  0.032,
#  0.333,
#  0.051,
#  0.134,
#  0.076,
#  0.034,
#  0.112,
#  0.078,
#  -0.003,
#  0.055,
#  -0.044,
#  -0.091,
#  0.042,
#  -0.019,
#  0.078,
#  0.05,
#  -0.038,
#  -0.106,
#  0.077,
#  0.06,
#  0.026,
#  0.102,
#  0.074,
#  -0.054,
#  0.145,
#  0.103,
#  0.029,
#  0.013,
#  -0.03,
#  -0.035,
#  0.049,
#  0.05,
#  0.016,
#  0.028,
#  0.077,
#  0.085,
#  0.088,
#  0.009,
#  0.067,
#  -0.011,
#  -0.097,
#  0.056,
#  0.096,
#  0.127,
#  -0.005,
#  0.031,
#  -0.081,
#  -0.038,
#  -0.019,
#  -0.043,
#  0.059,
#  0.01,
#  0.072,
#  0.054,
#  0.013,
#  0.007,
#  0.115,
#  -0.02,
#  0.061,
#  0.01,
#  0.059,
#  0.023,
#  -0.006,
#  -0.073,
#  0.024,
#  0.029,
#  -0.065,
#  0.037,
#  0.023,
#  0.03,
#  0.159,
#  -0.047,
#  -0.037,
#  0.016,
#  -0.069,
#  0.028,
#  0.123,
#  0.053,
#  0.044,
#  0.063,
#  0.029,
#  0.059,
#  0.083,
#  0.041,
#  0.038,
#  0.132,
#  0.032,
#  0.006,
#  -0.001,
#  0.028,
#  0.224,
#  0.045,
#  -0.036,
#  0.024,
#  0.0,
#  0.008,
#  -0.008,
#  0.021,
#  0.07,
#  0.101,
#  -0.023,
#  -0.099,
#  0.054,
#  -0.041,
#  0.077,
#  0.036,
#  0.039,
#  0.089,
#  0.104,
#  0.042,
#  0.012,
#  0.057,
#  0.032,
#  0.051,
#  0.083,
#  0.084,
#  -0.085,
#  0.057,
#  0.117,
#  -0.02,
#  0.049,
#  -0.003,
#  0.066,
#  -0.035,
#  -0.019,
#  -0.08,
#  -0.019,
#  0.145,
#  0.052,
#  0.167,
#  0.003,
#  0.04,
#  0.058,
#  0.217,
#  0.173,
#  0.182,
#  0.144,
#  0.173,
#  0.124,
#  0.149,
#  0.059,
#  0.231,
#  0.225,
#  0.036,
#  0.247,
#  0.337,
#  -0.019,
#  0.129,
#  -0.02,
#  0.227,
#  0.109,
#  0.051,
#  0.05,
#  0.224,
#  0.132,
#  0.066,
#  0.152,
#  0.204,
#  0.13,
#  0.219,
#  0.064,
#  0.09,
#  0.143,
#  -0.009,
#  0.259,
#  0.151,
#  -0.0,
#  0.183,
#  0.166,
#  0.055,
#  0.18,
#  0.242,
#  -0.017,
#  0.035,
#  0.114,
#  0.074,
#  0.065,
#  0.032,
#  0.136,
#  0.292,
#  0.22,
#  -0.044,
#  0.082,
#  0.045,
#  0.07,
#  0.106,
#  0.123,
#  0.009,
#  0.042,
#  0.095,
#  0.004,
#  0.006,
#  0.031,
#  0.215,
#  0.095,
#  0.154,
#  0.126,
#  0.101,
#  0.014,
#  0.096,
#  0.094,
#  0.084,
#  0.106,
#  0.036,
#  0.098,
#  0.019,
#  -0.027,
#  -0.017,
#  0.003,
#  0.091,
#  0.039,
#  0.001,
#  0.14,
#  0.025,
#  0.105,
#  0.268,
#  0.022,
#  0.1,
#  0.044,
#  0.161,
#  0.043,
#  0.078,
#  0.096,
#  0.073,
#  -0.014,
#  0.035,
#  0.004,
#  -0.062,
#  0.112,
#  0.065,
#  0.125,
#  0.032,
#  -0.043,
#  0.022,
#  0.015,
#  0.151,
#  0.046,
#  0.067,
#  0.083,
#  -0.008,
#  -0.074,
#  0.005,
#  0.04,
#  -0.043,
#  0.177,
#  0.087,
#  0.041,
#  0.102,
#  0.082,
#  0.058,
#  0.078,
#  0.156,
#  0.001,
#  0.151,
#  0.147,
#  0.059,
#  -0.02,
#  0.067,
#  0.134,
#  0.12,
#  0.218,
#  -0.039,
#  0.048,
#  0.01,
#  0.071,
#  -0.011,
#  0.087,
#  0.175,
#  0.129,
#  0.015,
#  0.04,
#  0.056,
#  0.059,
#  -0.055,
#  0.026,
#  0.04,
#  0.087,
#  -0.037,
#  0.021,
#  -0.012,
#  0.023,
#  -0.025,
#  0.269,
#  -0.026,
#  0.013,
#  0.009,
#  0.091,
#  0.031,
#  0.235,
#  0.117,
#  0.034,
#  0.002,
#  -0.044,
#  0.014,
#  0.066,
#  0.118,
#  0.023,
#  0.006,
#  -0.023,
#  0.043,
#  0.033,
#  0.028,
#  -0.067,
#  -0.002,
#  0.036,
#  -0.014,
#  0.08,
#  0.102,
#  0.009,
#  0.074,
#  -0.008,
#  0.025,
#  0.085,
#  -0.028,
#  0.051,
#  0.007,
#  0.03,
#  0.084,
#  0.011,
#  0.166,
#  0.049,
#  0.074,
#  0.006,
#  0.013,
#  0.034,
#  0.094,
#  -0.066,
#  0.069,
#  0.103,
#  0.154,
#  0.136,
#  0.003,
#  0.159,
#  0.015,
#  0.206,
#  0.127,
#  -0.016,
#  0.089,
#  0.098,
#  0.085,
#  -0.009,
#  0.031,
#  -0.023,
#  0.078,
#  -0.0,
#  -0.022,
#  0.027,
#  0.02,
#  0.011,
#  0.075,
#  0.115,
#  0.049,
#  -0.009,
#  0.035,
#  -0.015,
#  0.094,
#  0.187,
#  0.064,
#  0.012,
#  -0.071,
#  -0.031,
#  0.13,
#  0.15,
#  0.148,
#  0.071,
#  0.06,
#  0.127,
#  0.023,
#  0.175,
#  -0.007,
#  0.126,
#  0.118,
#  0.013,
#  0.091,
#  -0.002,
#  0.082,
#  0.098,
#  0.165,
#  0.038,
#  0.028,
#  -0.011,
#  0.067,
#  -0.082,
#  0.052,
#  0.071,
#  0.052,
#  0.212,
#  0.058,
#  -0.004,
#  0.092,
#  0.098,
#  0.145,
#  0.028,
#  0.091,
#  0.034,
#  0.145,
#  0.022,
#  0.019,
#  0.065,
#  -0.015,
#  0.094,
#  0.141,
#  0.01,
#  0.151,
#  0.055,
#  0.114,
#  0.137,
#  -0.017,
#  0.06,
#  -0.021,
#  0.232,
#  0.089,
#  0.161,
#  0.057,
#  0.259,
#  0.03,
#  0.157,
#  0.125,
#  0.176,
#  0.132,
#  0.104,
#  0.163,
#  0.143,
#  0.17,
#  0.185,
#  0.048,
#  0.123,
#  0.002,
#  -0.06,
#  -0.07,
#  -0.001,
#  0.043,
#  0.139,
#  0.157,
#  0.008,
#  0.016,
#  0.049,
#  0.062,
#  0.036,
#  0.065,
#  0.001,
#  0.081,
#  0.101,
#  0.014,
#  -0.003,
#  0.086,
#  0.109,
#  0.141,
#  0.051,
#  0.076,
#  0.085,
#  0.223,
#  0.074,
#  0.056,
#  0.169,
#  0.169,
#  0.115,
#  0.085,
#  0.032,
#  0.045,
#  0.064,
#  0.129,
#  0.138,
#  0.117,
#  0.017,
#  -0.037,
#  0.029,
#  0.085,
#  0.039,
#  0.066,
#  0.146,
#  -0.024,
#  0.052,
#  -0.016,
#  -0.002,
#  0.05,
#  -0.027,
#  0.106,
#  -0.003,
#  0.043,
#  0.036,
#  0.044,
#  0.13,
#  -0.055,
#  0.029,
#  0.037,
#  -0.044,
#  0.049,
#  -0.059,
#  0.056,
#  -0.074,
#  -0.003,
#  0.082,
#  -0.01,
#  -0.101,
#  0.053,
#  -0.034,
#  0.116,
#  0.253,
#  0.01,
#  0.09,
#  0.066,
#  0.015,
#  -0.073,
#  0.043,
#  -0.014,
#  -0.03,
#  0.183,
#  0.067,
#  0.07,
#  -0.045,
#  0.024,
#  ...]
