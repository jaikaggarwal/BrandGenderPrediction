# %%
import gensim.models.keyedvectors as word2vec
import time
import pandas as pd
import numpy as np
from mlxtend.evaluate import permutation_test
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize

import os

# %%
class Weat:
    def __init__(self, w2v_model, female_attr, male_attr):
        self.model = w2v_model
        self.female_attr = self.get_vecs(female_attr)
        self.male_attr = self.get_vecs(male_attr)
        self.vocab = [key.lower() for key in self.model.vocab.keys()]

    def get_vecs(self, word_list):
        vec_list = []
        for word in word_list:
            vec_list.append(self.model.get_vector(word))
        return vec_list

    def get_association(self, word):
        """

        :param word: brand to get association of
        :return: float. If positive, word is more female, if negative, word is more male.
        """
        try:
            word_vec = self.model.get_vector(word.capitalize())
        except KeyError:
            index = self.vocab.index(word)
            word_vec = self.model.get_vector(self.model.index2entity[index])
        female_mean = np.asarray([])
        male_mean = np.asarray([])
        for fem_vec in self.female_attr:
            female_mean = np.append(female_mean, cosine_similarity(fem_vec.reshape(1, -1), word_vec.reshape(1, -1))[0][0])
        for male_vec in self.male_attr:
            male_mean = np.append(male_mean, cosine_similarity(male_vec.reshape(1, -1), word_vec.reshape(1, -1))[0][0])
        return np.average(female_mean) - np.average(male_mean)

    def normalize(self, female_attr, male_attr):
        self.model.init_sims(replace=True)
        self.female_attr = self.get_vecs(female_attr)
        self.male_attr = self.get_vecs(male_attr)

# %%
# Load word vector
model = word2vec.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)

# %%
vocab = model.vocab.keys()

# %%
idx = 290000
list(vocab)[idx:idx+1000]
# Out:
# ['Frogster',
#  'Craig_Stebic',
#  'Methodist_Episcopal_Church',
#  'Castillian',
#  'Bayleys',
#  'Candy_Ride',
#  'BROOKINGS',
#  'Chris_Shuker',
#  '##.#mm_thick',
#  'Mamadi_Diane',
#  'staunchest_opponents',
#  'Bishop_Hendricken',
#  'bl',
#  'Balkin',
#  'Yablonski',
#  'Youre',
#  'ultra_luxurious',
#  'tog',
#  'Broadbridge',
#  'CIM_Standards',
#  'outer_fringes',
#  'By_DAVID_MURPHY',
#  'universally_acclaimed',
#  'Kaveh',
#  'procreative',
#  'Dumm',
#  'Servcorp',
#  'Kim_Young_sam',
#  'Compliment',
#  'Magnetic_Field',
#  'NYSE_LDK',
#  'Menangle',
#  'Bramham',
#  'SHOUT',
#  'Briski',
#  'Linthwaite',
#  'captain_Steve_Borthwick',
#  'Dunelm',
#  'Raheen',
#  'ROGERS_Ark.',
#  'Abbottabad_compound',
#  'Surat_Basin',
#  'LIMBAUGH',
#  'GERRY',
#  'Hamdard',
#  'Responsible_Gaming',
#  'Future_Generations',
#  'Kalima',
#  'Psalmist',
#  'Yell.com',
#  'McCutchan',
#  'Barcroft',
#  'EQUAL',
#  'votive',
#  'Pacing_Series',
#  'T.Stewart',
#  'baseman_Bret_Boone',
#  'PurchasePro',
#  'OpEd',
#  'hybrid_propulsion',
#  'EXIM_Bank',
#  'X_FAB',
#  'Formulate',
#  'Philip_Zelikow',
#  'semiconducting',
#  'Henricksen',
#  'Hyatt_Summerfield_Suites',
#  'Anandan',
#  'peekaboo',
#  'http://www.dfw.com',
#  'subclasses',
#  'TECSYS',
#  'EADS_Airbus',
#  '3yo',
#  'AMCOL',
#  'Sinan_Salaheddin_contributed',
#  'prolific_goalscorer',
#  'Sakakibara',
#  'Margaret_Witt',
#  'Mhlauri',
#  'Gottsch',
#  'Inc._NYSE_YUM',
#  'voter_disenfranchisement',
#  'NHTSA_Administrator',
#  'CHEC',
#  'WOA',
#  'CuEq',
#  'principal_Flavio_Briatore',
#  'speakerphones',
#  'Airship',
#  'Andrew_Crofts',
#  'Peppa_Pig',
#  'lv_denied',
#  'Lewan',
#  'Battiste',
#  'McLucas',
#  'Benjamin_Agosto',
#  'supped',
#  'dinging',
#  'disapointed',
#  'spoke_alloy_wheels',
#  'Abiding',
#  'Adam_MacDougall',
#  'verbatim_interviews',
#  'Greg_Grunberg',
#  'Antoniou',
#  'Petroceltic',
#  'Makati_Mayor_Jejomar',
#  'Clifden',
#  'Best_Documentary_Feature',
#  'Sid_Hartman',
#  'Hartz_Mountain',
#  'Farrish',
#  'Khin_Maung_Win',
#  'rocky_outcrops',
#  'Suswam',
#  'Waynoka',
#  'Vally',
#  'GlobeOp',
#  'PhotoWorks',
#  'planter_boxes',
#  'servers_workstations',
#  'N#.#billion',
#  'U_Conn',
#  'Bullfrog_Power',
#  'St._Stanislaus_Kostka',
#  'Bel_Air_mansion',
#  'Jaca',
#  'farted',
#  'NIPC',
#  'oct',
#  'handwriting_samples',
#  'intiative',
#  'Hagey',
#  'Chadian_rebel',
#  'Guy_Shepherdson',
#  'mortar_shells_landed',
#  'Genealogists',
#  'paintballing',
#  'Fabien_Pelous',
#  'Memory_Stick_PRO_Duo',
#  'single_malt_whiskey',
#  'RIDER',
#  'Justice_Iftikhar_Muhammad_Chaudhry',
#  'Barbar',
#  'Kumite',
#  'Specializes',
#  'Gondar',
#  'exacting_specifications',
#  'Quarterback_Aaron_Rodgers',
#  'pallid_sturgeon',
#  'Francis_Escudero',
#  'Mochi_Media',
#  'OSPIRG',
#  'Kiptyn',
#  'stogies',
#  'Bt2',
#  'Killin',
#  'Markets_http://www.researchandmarkets.com',
#  'NZOC',
#  'habitual_frequent',
#  'Cheddar_cheese',
#  'Exit_Poll',
#  'Figurs',
#  'Helping_Families',
#  'Lea_Ann',
#  'Deveny',
#  'Sarat',
#  'ravenous_appetite',
#  'Malcolm_Gladwell_Little',
#  'Haymore',
#  'waxworks',
#  'Punch_Bowl',
#  'upskilling',
#  'Brislin',
#  'Bellefield',
#  'CC####',
#  'Rocknroll_Hanover',
#  'Idealism',
#  'Volvo_Aero',
#  'Prem_Singh',
#  'Seraphine',
#  'Nataline',
#  'Galatians',
#  'Niyamgiri',
#  'Vittel',
#  'FC_Cologne',
#  'peice',
#  'Mages',
#  'Chrisette_Michele',
#  'tectonics',
#  'Ostrum',
#  'LHW',
#  'Flushing_Meadow',
#  'Garrison_LLP',
#  'Security_Council_SNSC',
#  'NTRglobal',
#  'damndest',
#  'Refugee_Action',
#  'unpleasantly_surprised',
#  'Harmonies',
#  'Career_Mode',
#  'Ph.D._MPH',
#  'ArtsQuest',
#  'Ayles',
#  'BoDeans',
#  'Rep._Walt_Minnick',
#  'SEABL',
#  'Pigment',
#  'Straw_Hat',
#  'deadbolts',
#  'respiratory_distress_syndrome',
#  'NetGear',
#  'brother_Shahbaz',
#  'overturned_tractor_trailer',
#  'Christina_Hoag',
#  'skulked',
#  'Champions_Biotechnology',
#  'spleens',
#  'Murfin',
#  'Derek_Walcott',
#  'Frisco_RoughRiders',
#  'Harpin',
#  'thirst_quenching',
#  'revolutionary_Che_Guevara',
#  'Renault_Laguna',
#  'sheepherders',
#  'Senator_Tom_Daschle',
#  'Leadis',
#  'Tinner',
#  'Jobling',
#  'Youth_Hostel',
#  'Berget',
#  'Feel_Better',
#  'BMICH',
#  'CYCLE',
#  'Fiesta_subcompact',
#  'Ashkenaz',
#  'dry_rot',
#  'Attendances',
#  'Amy_Brenneman',
#  'Houze',
#  'Leigertwood',
#  'Treadaway',
#  'Syed_Salahuddin',
#  'Ahmed_Yassin',
#  'Jaminez',
#  'native_Minnesotan',
#  'Galassi',
#  'shortstop_Angel_Berroa',
#  'Zinder',
#  'drip_drip',
#  'Ensemble_Studios',
#  'Cesar_Armando_Laurean',
#  'postherpetic_neuralgia',
#  'Veritec',
#  'Zach_Greinke',
#  'Minister_Abdul_Rahim',
#  'Dashain',
#  'LifeStyle',
#  'Chane',
#  'Yaffa',
#  'Love_Waits',
#  'burning_fireplace',
#  'Smithsonian_Astrophysical_Observatory',
#  'STAT_OF_THE',
#  'Demian',
#  'nuclear_scientist_AQ',
#  'Kurt_Elling',
#  'Jhonny_Gonzalez',
#  'Toons',
#  'et_la',
#  'jobseeker_allowance',
#  'Zahm',
#  'Freels',
#  'Pediatric_Dentistry',
#  'Paranormal_Research',
#  'Maccabiah',
#  'indoor_batting_cage',
#  'IRU',
#  'Braids',
#  'ONTs',
#  'smuggle_explosives',
#  'Ice_Capades',
#  'Bravehearts',
#  'Minister_Siti_Fadilah',
#  'Pasco_Hernando_Community',
#  'Woodwind',
#  'polar_bear_Knut',
#  'La_Furia_Roja',
#  'Dick_Thornburgh',
#  '9am_AEST',
#  'SPRINGFIELD_NJ',
#  'reusable_containers',
#  'Master_Franchise',
#  'Alex_Gidman',
#  'FOLFOX',
#  'Orab',
#  'holistic_healing',
#  'BCS_busters',
#  'YourFindit',
#  'vilazodone',
#  'Confidence_Survey',
#  'PPCC',
#  'Rod_Steiger',
#  'Tribhuvan_University',
#  'Tuz',
#  'czarist',
#  'Churachandpur_district',
#  'languor',
#  'Bloomin',
#  'Selfridge_Air',
#  'Bizkaia',
#  'nickel_cobalt',
#  'Mankell',
#  'Ruled_Out',
#  'NAVSEA',
#  'Raisins',
#  'ejector',
#  'collectivity',
#  'D._Dingell',
#  'Bolani',
#  'Onawa',
#  'Linda_Norgrove',
#  'Betty_Castor',
#  'spokesman_Michael_Drewniak',
#  'souq',
#  'Spyker_Cars_NV',
#  'Li_Ion',
#  'Coyote_Ridge',
#  'Alicia_Caldwell',
#  'Alex_Henery',
#  'rubbished_suggestions',
#  'frost_bite',
#  'dose_limiting_toxicities',
#  'nasa',
#  'food_pantries_soup_kitchens',
#  'Albany_Med',
#  'Climate_Change_DECC',
#  'Kevin_Parrom',
#  'LPL_Financial_Services',
#  'adjunctive_treatment',
#  'Gorseinon',
#  'Brett_Geeves',
#  'Kozloduy',
#  'sheep_grazing',
#  'Archived_images',
#  'Electronic_Warfare',
#  'RuggedCom',
#  'IMOCA',
#  'Midnight_Run',
#  'Braund',
#  'Cytopia',
#  'doorbell_rings',
#  'SQL_databases',
#  'pitcher_Sidney_Ponson',
#  'Savovic',
#  'DeLisi',
#  'Mutlaq',
#  'Kazuhiro_Sasaki',
#  'shrewd_politician',
#  'dopamine_neurons',
#  'Counsel_Fred_Fielding',
#  'Droves',
#  'Kathy_Mattea',
#  'Friendship_Circle',
#  'sympathies_lie',
#  'VEGAS.com',
#  'SolidWorks_Corporation',
#  'VID',
#  'NoHo',
#  'Vincennes_Ind.',
#  'baseman_Russell_Branyan',
#  'Corporation_NYSE_LNC',
#  'Coolbeth',
#  'Riz',
#  'ST####',
#  'XRX',
#  'closes_loophole',
#  'Stuart_Frankel',
#  'Fesmire',
#  "OBAMA_'S",
#  'Mario_Tama_Getty_Images',
#  'Triffids',
#  'Bernards_Township',
#  'CTRP',
#  'Socio',
#  'Mike_Splinter',
#  'referrer',
#  'Dame_Vera',
#  'Avanquest_Software',
#  'NASDAQ_COST',
#  'No_Gun_Ri',
#  'NAFO',
#  'VANESSA',
#  'commercialization_milestones',
#  'Symantec_Backup_Exec',
#  'impatiently_waiting',
#  'Lower_Merion_Township',
#  'Upholds',
#  'Dandala',
#  'Niman',
#  'REVIEWS',
#  'Acra',
#  'Raffle_prizes',
#  'coronary_angiography',
#  'mil_lion',
#  'Spaceballs',
#  'www.itunes.com/appstore/',
#  'Degan',
#  'incommunicado_detention',
#  'Manuka',
#  'Kanzius',
#  'Wenke',
#  "N'Sync",
#  'ADTECH',
#  'sustained_mild_concussion',
#  'Sennott',
#  'Chicot',
#  'recommendable',
#  'HOBOKEN',
#  'epigraph',
#  'Champaign_IL',
#  'Jim_Langevin',
#  'Carlgren',
#  'Koranic_verses',
#  'erect_monument',
#  'EATON',
#  'ADSB',
#  'weekâ_€_™',
#  'Draft_Picks',
#  'DAVIDSON_NC',
#  'WorldPay',
#  'Yann_Martel',
#  'VXR',
#  'Etchison',
#  'Vandenbroucke',
#  'Bagalkot',
#  'potty_humor',
#  'AAEP',
#  'Lianna',
#  'Begbie',
#  'Bestway',
#  'Mediapart',
#  'Heather_Clancy',
#  'Supervisors_voted_unanimously',
#  'Colen',
#  'Jimmy_Kebe',
#  'Saw_Mill_River',
#  'NYSE_VG',
#  'isolated_tornadoes',
#  'Dr._Parnassus',
#  'Ruby_Dhalla',
#  'advisor_Karl_Rove',
#  'Thomson_CCBN_s',
#  'Starting_Blocks',
#  'greenstone_belt',
#  'Equitrac',
#  'Wingspan',
#  'Pantanal',
#  'Tebbe',
#  'tentpoles',
#  'Eyelit',
#  'genuflecting',
#  'Barzilai',
#  'Aldersgate',
#  'passably',
#  'Soul_Kitchen',
#  'couple_honeymooned',
#  'gastrointestinal_GI',
#  'Cyclades',
#  'Junior_Stanislas',
#  'kvetch',
#  'Silent_Movie',
#  'Filipino_seamen',
#  'Ye_Xie',
#  'Posts_Lower',
#  'Lopata',
#  'Tinkoff',
#  'Auto_Dealer',
#  'Copperhead_course',
#  'By_TIM_KLASS',
#  'goaltender_Kari_Lehtonen',
#  'Roseanna',
#  'Oil_Rig',
#  'LaBounty',
#  'Rafidah_Aziz',
#  'Schiffrin_Barroway_Topaz',
#  'blindside_flank',
#  'SkypeIn',
#  'Woolcock',
#  'Younce',
#  'Columbus_Crew_Stadium',
#  'talus',
#  'morbid_fascination',
#  'McGonegal',
#  'Joe_Tripodi',
#  'Diagnostic_Laboratory',
#  'Unethical',
#  'Jim_Thome_homered',
#  'SNDA',
#  'zombie_flick',
#  'ISMI',
#  'Killing_Joke',
#  'KSD',
#  'Aristotelian',
#  'Lottery_Corporation_WCLC',
#  'MyRide.com',
#  'eggy',
#  'Beyrle',
#  'geodetic',
#  'Am_Telling_You',
#  'GRANTS_PASS',
#  'Board_SASB',
#  'Sprenkle',
#  'WESCO',
#  'EA_Diddle_Arena',
#  'Takoma',
#  'ROMANCE',
#  '###Mbit_s',
#  'Melquiades_Estrada',
#  'Laotians',
#  'Maimone',
#  'setantasports.com',
#  'CME_ClearPort',
#  'Telaprevir',
#  'offsprings',
#  'Adjuvant',
#  'Brading',
#  'INFY',
#  'fraudulence',
#  'DecisionPoint',
#  'Ramgoolam',
#  'Freeware',
#  'Spectra_Energy_Partners',
#  'Vonage_Holdings',
#  'Pound_sterling',
#  'petroleum_refiner',
#  'Commissions_trailing',
#  'Rly',
#  'topological',
#  'Hosny',
#  'Hg',
#  'Oglebay',
#  'BlackBerry_Tablet',
#  'mg_BID',
#  'Microsoft.com',
#  'Hans_Raj',
#  'VHGI',
#  'International_NYSE_EIX',
#  'azathioprine',
#  'Starter_Pack',
#  'Agnico',
#  'Valier',
#  'THE_POLICIES_OF',
#  'IronPort_Systems',
#  'hollandaise_sauce',
#  'PlayReady',
#  'Campy',
#  'Music_Downloads',
#  'IEB',
#  'Telephone_Cooperative',
#  'ParaScale',
#  'Vinexpo',
#  'middleweight_champ',
#  'Mount_Tamalpais',
#  'Burrup',
#  'Kamini',
#  'appeaser',
#  'Finmeccanica_SpA',
#  'Bracha',
#  'Jackass_Number_Two',
#  'Mackall',
#  'Ieuan_Wyn_Jones',
#  'champion_Evan_Lysacek',
#  'Wilmut',
#  'falsely_inflated',
#  'io9',
#  'anodes',
#  'inadvertently_omitted',
#  'DERA',
#  'Guangdong_Provincial',
#  'CONTAINS_FORWARD_LOOKING_STATEMENTS',
#  'MINISTER_OF',
#  'POWAY',
#  'pelvic_exam',
#  'Trent_Waterhouse',
#  'Shuttle_Launch',
#  'Shangri_La_Dialogue',
#  'insatiable_curiosity',
#  'Gosnold',
#  'John_Acher',
#  'Lehrmann',
#  'Folha',
#  'Bonnie_Fuller',
#  'CWA_Local',
#  'RDF_Media',
#  'Overlook_Hospital',
#  'Rott',
#  'Whose_Line',
#  'Hesitant',
#  'sacrificial_animals',
#  'Aqil',
#  'Terra_Ventures',
#  'Paul_Theroux',
#  'PCAR',
#  'BIGS',
#  'STOPPED',
#  'optoelectronic_devices',
#  'Abdul_Wali',
#  'Videographer',
#  'Telepictures_Productions',
#  'polio_syndrome',
#  'blowfish',
#  'Spectrum_Control',
#  'remarket',
#  'AOTMP',
#  'Unluckily',
#  'spokesman_Philippe_Reines',
#  'defender_Carles_Puyol',
#  'BRN',
#  'evaporative_cooling',
#  'videocamera',
#  'Mon_Wed',
#  'Brookhouse',
#  'Wrecker_Service',
#  'Solomon_Lew',
#  'Conesville',
#  'amino_acid_sequence',
#  'debottlenecking',
#  'Tardio',
#  'Capulet',
#  'Linguini',
#  'Bocca',
#  'Brandywine_Heights',
#  'Derham',
#  'unauthenticated',
#  'Herding',
#  'INI',
#  'Sensient',
#  'Michael_Zucchet',
#  'Kidapawan_City',
#  'Arid',
#  'Hansie',
#  'tunesmith',
#  'Cambron',
#  'McErlean',
#  'Babyshambles_singer',
#  'perpendicular_recording',
#  'President_Henrique_Meirelles',
#  'Scarr',
#  'Childish',
#  'Rusafa',
#  'Rosanna_Arquette',
#  'Yasmina',
#  'Caffee',
#  'DETERMINED',
#  'amusement_arcade',
#  'Petherton',
#  'Hiltner',
#  'Perceptive_Software',
#  'Downpour',
#  'Mark_Truby',
#  'Search_Engine_Optimisation',
#  'FlatOut',
#  'Bernard_Jackman',
#  'Eric_Rohmer',
#  'BOULEVARD',
#  'Tamil_Nadu_Karnataka',
#  'Alexandre_Daigle',
#  'clindamycin',
#  'prostate_specific',
#  'Zorich',
#  'linear_regression',
#  'HTCC',
#  'Monba',
#  'shuras',
#  'sh###b',
#  'Cliché',
#  'Shillito',
#  'European_planemaker_Airbus',
#  'GIVE_LIFE',
#  'Philippians',
#  'Rosewall',
#  'nullahs',
#  'Muqdadiya',
#  'cognitive_psychology',
#  'dense_jungles',
#  'OMV_AG',
#  'neurotoxic',
#  'Rex_Nutting_MarketWatch',
#  'Byran',
#  'Paul_Ryan_R-Wis.',
#  'Man_Pleads_Not',
#  'BONNIE',
#  'visit_www.rmclasslaw.com_cases',
#  'outfielder_Jermaine_Dye',
#  'Laure_Manaudou',
#  'pref',
#  'Inc._Nasdaq_AMAT',
#  'Tardelli',
#  'Chatham_Borough',
#  'Semple_Stadium',
#  'conventionally_powered',
#  'DERC',
#  'wax_nostalgic',
#  'Ramesh_Chandra',
#  'lock_Victor_Matfield',
#  'Heun',
#  'Zaruba',
#  'Memorandums',
#  'Shap',
#  'Midget_AAA',
#  'Nutritious',
#  'Climaco',
#  'Bulgargaz',
#  'NCSD',
#  'Goller',
#  '###th_Parachute_Infantry_Regiment',
#  'Konar',
#  'Forsell',
#  'sleepily',
#  'penitential',
#  'Winemaking',
#  'ManYoo',
#  'leafy_suburb',
#  'Suburban_Journals',
#  'neural_connections',
#  'Sferrazza',
#  'EPCC',
#  'loaf_pan',
#  'lakh_metric_tonnes',
#  'KSI',
#  'LME_aluminum',
#  'Indianness',
#  'Fern_Ridge',
#  'outskated',
#  'moisture_wicking',
#  'Burhans',
#  'pastor_Rev._Jeremiah',
#  'Untapped',
#  'Honolulu_Symphony',
#  'Salai',
#  'Giant_Steps',
#  'Scarfo',
#  'Radjabov',
#  'analyst_Ray_Neidl',
#  'Confinement',
#  'Amdahl',
#  'Maoist_stronghold',
#  'Metaphysical',
#  'sworn_allegiance',
#  'Isabelle_Dinoire',
#  'Motion_Controller',
#  'Zaken',
#  'Mattsson',
#  'Red_Carpet_Photos',
#  'stan',
#  '1UP.com',
#  'matrics',
#  'Ltd_SAIL',
#  'Weyland',
#  'Fucci',
#  'outdoor_rinks',
#  'Lance_Jeter',
#  'Gold_Nugget',
#  'Article_PubMed_ChemPort',
#  'ESCs',
#  'Maack',
#  'By_RICK_BENTLEY',
#  'worklessness',
#  'sleekest',
#  'steadfast_ally',
#  'vanned',
#  'Makar_Sankranti',
#  'Ahmedabad_Gujarat',
#  'freelance_cameraman',
#  'Sam_Cowart',
#  'batten',
#  'Zamil',
#  'Peachtree_Industrial',
#  'Pointe_Coupee',
#  'JG_TC',
#  'Making_Strides',
#  'pellet_stove',
#  'Southwest_Airlines_LUV',
#  'Transportation_Worker_Identification',
#  'bilaterals',
#  'Campolo',
#  'Sharif_Sheikh',
#  'IGM_Financial',
#  'reports_imdb.com',
#  'Lerche',
#  'TRUMP',
#  'fudges',
#  'SGVN_Staff_Photo',
#  'Wallinger',
#  'Legal_Issues',
#  'Giles_Elgood',
#  '##:##:##_UTC',
#  '------------_+',
#  'Ovaltine',
#  'Brewis',
#  'AoC',
#  'Rapidly_rising',
#  'jostles',
#  'Coast_Guard_Lt._Cmdr',
#  'AFC_Telford_United',
#  'Samsung_Captivate',
#  'Headmasters',
#  'Novar',
#  'Sainte_Marie',
#  'Anderegg',
#  'Willsey',
#  'Shiley',
#  'Online_Subscriber_content',
#  'DLGF',
#  'Prokopcuka',
#  'Koel',
#  'optionality',
#  'prized_scalp',
#  'Loblaw_Companies_Limited',
#  'starter_Clay_Buchholz',
#  'Zarand',
#  'Brevan_Howard',
#  'Easy_Bake_Oven',
#  'Serum_Institute',
#  'Bob_Debus',
#  'Vince_Lombardi_trophy',
#  'Forté',
#  'Andre_Greipel',
#  'Disaboom',
#  'TV_LAND_SPIKE',
#  'Tuebingen',
#  'SAMBA',
#  '##GB_capacities',
#  'Banner_Elk',
#  'As_Swiss_Verein',
#  'Newsreel',
#  'blankets_pillows',
#  'SUMO',
#  'accoutrement',
#  'ruthlessly_efficient',
#  '¢_â_€_žÂ',
#  'Broadway.com_Staff',
#  'melodica',
#  'NIMASA',
#  'Essure_procedure',
#  'beacuse',
#  'joing',
#  'Senator_Amy_Klobuchar',
#  'Advocat',
#  'Supercomm',
#  'Criminologist',
#  'golden_haired',
#  'Lee_Strasberg',
#  'Saye',
#  'Parascript',
#  'Lupane',
#  'curb_underage_drinking',
#  'tomcat',
#  'ClearPath',
#  'ARIA_Awards',
#  'Palarong_Pambansa',
#  'Scailex',
#  'Akume',
#  'Budweiser_Chevrolet',
#  'thou_shall',
#  'Hortons',
#  'capital_Antananarivo',
#  'Pierre_LeBrun',
#  'Premont',
#  'Christy_Ring',
#  'GTi',
#  'Shaquan_Duley',
#  'Brainy',
#  'Shane_Lechler',
#  'postward',
#  'Harbor_Shores',
#  'Blaize',
#  'Logan_Magnolia',
#  'TTY_#-###-###-####',
#  'Menk',
#  'authenticator',
#  'WELCH',
#  'Improvised_Explosive_Device_IED',
#  'Rickard_Wallin',
#  'School_Book_Depository',
#  'tacit_acceptance',
#  'Bantustans',
#  'Agricultural_Economics',
#  'Juhnke',
#  'fascinator',
#  'Brass_Rail',
#  'Darryl_Dyck',
#  'Ashok_Todi',
#  'Tiko',
#  'Meena_Kumari',
#  'By_KEVIN_MARTIN',
#  'kanal',
#  'Place_Finish',
#  'Marred',
#  'Lori_Berenson',
#  'Buzard',
#  'BNSF_Railway_Co.',
#  'Fairer',
#  'Bernard_Herrmann',
#  'freshman_Tyler_Clementi',
#  'Kordan',
#  'bitrates',
#  'Limoneira',
#  'NOF',
#  'pro_choicers',
#  'Briancon',
#  'Circassian',
#  'Jonathan_Ive',
#  'Danao',
#  'Amit_Singh',
#  'Specialty_Metals',
#  'glycemic_load',
#  'LISBON_Reuters',
#  'Alexander_Wurz',
#  'Doland',
#  'Selley',
#  'Shirky',
#  'Rashaun_Woods',
#  'Brian_Stann',
#  'dipped_strawberries',
#  'Vautour',
#  'Penn_Schoen_&',
#  'Phelpses',
#  'Ferenc_Puskas',
#  'Sutanto',
#  '##PM_ET_PT',
#  'Equating',
#  'VanderBeek',
#  'Kashiwazaki_Kariwa_nuclear',
#  'Goude',
#  'Danilkin',
#  'Marzo',
#  'antibody_therapeutics',
#  'Pomona_Raceway',
#  'NineMSN',
#  'Panjabi',
#  'Baby_Spice',
#  'Crop_Production',
#  'Arsenal_goalkeeper_Jens',
#  'Al_Quoz',
#  'hamburger_buns',
#  'EILEEN_SULLIVAN',
#  'Wylys',
#  'Garrettsville',
#  'Stephen_McCausland',
#  'Rumors_abound',
#  'Widowmaker',
#  'Tolin',
#  'Llambias',
#  'Boombox',
#  'defender_Thomas_Vermaelen',
#  'Leonardo_Di_Caprio',
#  'Ariba_Spend_Management',
#  'H1_FORECASTS_Sales',
#  'Momah',
#  'mathematical_concepts',
#  'By_Aung_Hla',
#  'Suriano',
#  'Zaro',
#  'FIBT',
#  'Wadadah',
#  'embedded_semiconductors',
#  'shafting',
#  'interlibrary_loan',
#  'HEAD_TO',
#  'Ctrip.com',
#  'Okavango',
#  'gaudy_statistics',
#  'Aletha',
#  'cookie_recipes',
#  'environ',
#  'Yunits',
#  'Fota',
#  'Cesarewitch',
#  'Project_Lifeline',
#  'Darting',
#  'TORONTO_Ont',
#  'Clay_Shirky',
#  'Hecla_Mining_Co.',
#  'silty',
#  'makeready',
#  'MedStar_Health',
#  'Kerravala',
#  'griffin',
#  'Drinker',
#  'Menjivar',
#  'cordwood',
#  'Emirates_Towers',
#  'Nozomi',
#  'CrossRoads',
#  'stark_reminders',
#  'Mark_Burchill']

# %%
# Preprocess vocabulary and get rid of capital letters that aren't at the beginning of a sentence
# This is to distinguish between brands and general uses of brands that are words
vocab = model.vocab.keys()
vocab = [v.lower() for v in vocab]

# %%
# Load brand name data frame, keep brands that are in word2vec model
df = pd.read_csv('../Brand-Name-Gender-Prediction/brand_names_coded.csv')
df = df[df['BRAND'].isin(vocab)]
df = df[['BRAND', 'CATEGORY']]

# %%
# Get female and male attributes
male = []
female = []
with open('pairs_paper.txt', 'r') as file:
    data = file.readlines()
    data = [line.strip() for line in data]
    for line in data:
        sub = line.split(', ')
        female.append(sub[0])
        male.append(sub[1])

weat = Weat(w2v_model=model, female_attr=female, male_attr=male)
print(female)
print(male)
# Out:
# ['she', 'her', 'woman', 'Mary', 'herself', 'daughter', 'mother', 'gal', 'girl', 'female']
# ['he', 'his', 'man', 'John', 'himself', 'son', 'father', 'guy', 'boy', 'male']

# %%
# Unnormalized cosine similarities
df['UNNORMALIZED WEAT'] = df['BRAND'].apply(lambda x: weat.get_association(x))
df['UNNORMALIZED WEAT GENDER'] = df['UNNORMALIZED WEAT'].apply(lambda x: 'F' if x > 0 else 'M')
pd.DataFrame(df).to_csv('unnormalized_weat.csv')

# %%
df.drop_duplicates(subset='BRAND')['UNNORMALIZED WEAT GENDER'].value_counts()
# Out:
# F    959
# M    512
# Name: UNNORMALIZED WEAT GENDER, dtype: int64
