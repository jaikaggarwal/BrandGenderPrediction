# %% [markdown]
# Two main tasks for this notebook.
# 1) Plot brand gender against category usage gender.
# 2) 1d jitter plot of brands against heshe axis
# 3) Get better unstanding of the gender-classifying algorithm.

# %%
import gensim.models.keyedvectors as word2vec
import time
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize
import os
import matplotlib.pyplot as plt
from pylab import *
import scipy
import string

# %%
#Plot brand gender against category
# Step 1: Find relative femaleness of each category (what percent is female in each)
# Step 2: Plot what percentage of TOTAL female brands are found in each category
df = pd.read_csv('glove_he_she_category_value_counts.csv', header=None)
df_gloss = pd.read_csv('glossary.csv')
df = df[df[0] != 'BASELINE']
df_sums = df.groupby(0).sum()
df_female = df[df[1] == 'F']
missing = set(df_sums.index.tolist()).difference(set(df_female[0].tolist()))
for item in missing:
    df_female = df_female.append({0: item, 1: 'F', 2: 0}, ignore_index=True)
df_joined = pd.merge(df_sums, df_female, on=0)
df_joined['brand_femaleness'] = df_joined['2_y'] / df_joined['2_x']
df_joined = df_joined.sort_values(by='brand_femaleness')
# if df_gloss.shape[0] == df_joined.shape[0]:
df_joined['category_femaleness'] = df_gloss['category_femaleness']
# else:
#     print("What in heck")
    
df_joined

# total_female = df_female.sum()[2]
# df_joined['brand_femaleness'] = df_joined['2_y'] / total_female
# df_joined
# Out:
#                                                 key_0  2_x  1  2_y  \
# 27     D259 Womens Shaving Supplies General Promotion    1  F    0
# 28  D269 Deodorants & Antiperspirants General Prom...    1  F    0
# 29  D439 Mens Shaving Equipment & Supplies General...    7  F    1
# 12                             B511 Desktop Computers   10  F    2
# 58                           H310 Household Batteries    9  F    2
# 51      G511 Elec & Video Games & Sftwr (Excl PC&Net)   14  F    4
# 14         B541 Web Design, Domain & Hosting Services   14  F    4
# 50              G499 Sporting Goods General Promotion   26  F    8
# 13               B521 Printers & Printing Accessories   16  F    5
# 72                         V365 Sporting Goods Stores    6  F    2
# 24         D183 Men's Scents, Fragrances, Aftershaves    6  F    2
# 60                        H413 Dishwashing Detergents    3  F    1
# 65                          T141 Automotive Batteries    3  F    1
# 25  D189 Fragrances, General Promotion/Multi-Categ...    3  F    1
# 31  D529 Cold, Cough, Sinus & Asthma Remdies:Comb ...    5  F    2
# 64      T139 Vehicles, Sales & Leasing: Comb Copy&NEC   15  F    6
# 10          B322 Religious, Charitable & Humanitarian   10  F    4
# 6   B122 Investment Products & Services (Excluding...   77  F   31
# 44                            F611 Regular Beer & Ale   62  F   25
# 45                          G141 Cameras (Excl Video)   19  F    8
# 17                B721 Office Furniture & Accessories   27  F   12
# 0                      A141 Sportswear & Athleticwear  121  F   54
# 63                                         H631 Paint   11  F    5
# 11                  B430 Insurance Agencies & Brokers   13  F    6
# 4                                     A430 Sunglasses   19  F    9
# 7     B124 Loan/Credit Products & Services (Consumer)   40  F   19
# 48                    G411 Fishing Tackle & Equipment   42  F   20
# 18      B722 Stationery,Greeting Cards&Misc Paper Gds   23  F   11
# 5                                   B111 Credit Cards   29  F   14
# 36        F259 Pasta & Pasta Dishes General Promotion    2  F    1
# ..                                                ...  ... ..  ...
# 32                       D543 Nutritional Supplements  138  F   84
# 38         F313 Ice Cream, Frozen Novelties & Sherbet   41  F   25
# 34                                  F122 Cooking Oils   21  F   13
# 49       G451 Snow Skis, Boards, Blades & Accessories   16  F   10
# 70                                    V363 Toy Stores    3  F    2
# 56                              H142 Bedding & Linens   37  F   25
# 19                           B913 Employment Agencies   22  F   15
# 43  F539 Chips, Nuts, Popcorn & Pretzels General P...   13  F    9
# 39                            F343 Cookies & Crackers   33  F   23
# 59          H339 Household Paper Products: Comb & NEC   11  F    8
# 57                             H213 Laundry Equipment   11  F    8
# 53                    G613 Cat & Dog Food Combination   13  F   10
# 15        B641 TV Networks, Stations & Production Cos   35  F   27
# 22          D181 Women's Scents, Fragrances, Perfumes    9  F    7
# 54               H111 Dinnerware, Glassware & Pottery   36  F   28
# 3                                       A411 Handbags   28  F   22
# 40                                        F411 Coffee   14  F   11
# 66                            T412 Cruise Ship Travel   20  F   16
# 20  D119 Skin Care Products, General Promotion/Mul...   46  F   37
# 55                      H122 Mattresses & Box Springs   39  F   32
# 1                           A311 Womens Shoes & Boots   52  F   43
# 33                         F113 Artificial Sweeteners    7  F    6
# 30                                 D511 Pain Remedies   11  F   10
# 21  D149 Face Makeup, General Promotion/Multi-Cate...    4  F    4
# 41                        F413 Cocoa & Milk Additives    6  F    6
# 71                          V364 Hobby & Craft Stores    1  F    1
# 68                T440 Amusement, Water & Theme Parks    2  F    2
# 69                                  V131 Beauty Shops    2  F    2
# 23           D182 Unisex Scents, Fragrances, Perfumes    1  F    1
# 47                    G324 Coffee & Donut Restaurants    2  F    2
#
#     brand_femaleness  category_femaleness
# 27          0.000000                 1.00
# 28          0.000000                 0.50
# 29          0.142857                 0.40
# 12          0.200000                 0.20
# 58          0.222222                 0.15
# 51          0.285714                 0.20
# 14          0.285714                 0.50
# 50          0.307692                 0.50
# 13          0.312500                 0.30
# 72          0.333333                 0.40
# 24          0.333333                 0.30
# 60          0.333333                 0.80
# 65          0.333333                 0.10
# 25          0.333333                 0.80
# 31          0.400000                 0.50
# 64          0.400000                 0.10
# 10          0.400000                 0.60
# 6           0.402597                 0.20
# 44          0.403226                 0.10
# 45          0.421053                 0.40
# 17          0.444444                 0.30
# 0           0.446281                 0.50
# 63          0.454545                 0.30
# 11          0.461538                 0.20
# 4           0.473684                 0.80
# 7           0.475000                 0.20
# 48          0.476190                 0.10
# 18          0.478261                 0.50
# 5           0.482759                 0.30
# 36          0.500000                 0.60
# ..               ...                  ...
# 32          0.608696                 0.40
# 38          0.609756                 0.50
# 34          0.619048                 0.80
# 49          0.625000                 0.20
# 70          0.666667                 0.70
# 56          0.675676                 0.60
# 19          0.681818                 0.50
# 43          0.692308                 0.60
# 39          0.696970                 0.55
# 59          0.727273                 0.80
# 57          0.727273                 0.90
# 53          0.769231                 0.70
# 15          0.771429                 0.50
# 22          0.777778                 1.00
# 54          0.777778                 0.90
# 3           0.785714                 1.00
# 40          0.785714                 0.50
# 66          0.800000                 0.50
# 20          0.804348                 0.80
# 55          0.820513                 0.50
# 1           0.826923                 1.00
# 33          0.857143                 0.80
# 30          0.909091                 0.50
# 21          1.000000                 0.90
# 41          1.000000                 0.80
# 71          1.000000                 0.70
# 68          1.000000                 0.50
# 69          1.000000                 0.90
# 23          1.000000                 0.60
# 47          1.000000                 0.50
#
# [73 rows x 6 columns]

# %%
# x = set(df_joined['key_0'].tolist())
# l = []
# for index, row in df_gloss.iterrows():
#     l.append("".join([row['code'],row['category'][1:]]))
# x.difference(l)
df_gloss.shape
# Out:
# (73, 4)

# %%
rcParams['font.family'] = 'sans-serif'
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
x = []
y = []
for index, row in df_joined.iterrows():
    x.append(row['category_femaleness'])
    y.append(row['brand_femaleness'])
    plt.scatter(row['category_femaleness'], row['brand_femaleness'], c='black', s=1000, marker=r"$ {} $".format(row['key_0'][:5])) 
# plt.ylim(-0.01, 0.08)
plt.xlabel('Category Femaleness (%)')
plt.ylabel('Brand Femaleness (%)')
plt.title('Category Femaleness against Brand Femaleness from Glove Projections')
plt.plot(x, np.poly1d(np.polyfit(x, y, 1))(x))
plt.savefig('glove_category_vs_brand_femaleness.png')
plt.show()

# %%
# df_glossary = pd.DataFrame()
# df_glossary['code'] = df_joined['key_0'].apply(lambda x: x[:5])
# df_glossary['category'] = df_joined['key_0'].apply(lambda x: x[4:])
# df_glossary.sort_values(by='code').to_csv('glossary.csv')
print(x)
# Out:
# [1.0, 0.5, 0.4, 0.2, 0.15, 0.2, 0.5, 0.5, 0.3, 0.4, 0.3, 0.8, 0.1, 0.8, 0.5, 0.1, 0.6, 0.2, 0.1, 0.4, 0.3, 0.5, 0.3, 0.2, 0.8, 0.2, 0.1, 0.5, 0.3, 0.6, 0.7, 0.75, 0.4, 0.5, 0.55, 0.6, 0.5, 0.3, 0.5, 0.75, 0.2, 0.6, 0.5, 0.4, 0.5, 0.8, 0.2, 0.7, 0.6, 0.5, 0.6, 0.55, 0.8, 0.9, 0.7, 0.5, 1.0, 0.9, 1.0, 0.5, 0.5, 0.8, 0.5, 1.0, 0.8, 0.5, 0.9, 0.8, 0.7, 0.5, 0.9, 0.6, 0.5]

# %%
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)
print("Slope: {}\nIntercept: {}\nR-value: {}\nP-value: {}\nStd-error: {}".format(slope, intercept, r_value, p_value, std_err))
# Out:
# Slope: 0.4203138512055002
# Intercept: 0.3439775489342076
# R-value: 0.43260373970972926
# P-value: 0.00013220968083379106
# Std-error: 0.1039586265403047

# %%
#Plot brand gender against category when brands that are like names are ommitted
# Step 1: Find relative femaleness of each category (what percent is female in each)
# Step 2: Plot what percentage of TOTAL female brands are found in each category
df_nn = pd.read_csv('glove_he_she_category_value_counts_no_names.csv', header=None)
df_nn = df_nn[df_nn[0] != 'BASELINE']
df_sums_nn = df_nn.groupby(0).sum()
df_female_nn = df_nn[df_nn[1] == 'F']
missing_nn = set(df_sums_nn.index.tolist()).difference(set(df_female_nn[0].tolist()))
for item in missing_nn:
    df_female_nn = df_female_nn.append({0: item, 1: 'F', 2: 0}, ignore_index=True)
df_joined_nn = pd.merge(df_sums_nn, df_female_nn, on=0)
df_joined_nn['brand_femaleness'] = df_joined_nn['2_y'] / df_joined_nn['2_x']
df_joined_nn = df_joined_nn.sort_values(by='brand_femaleness')
df_joined_nn['key_0'] = df_joined_nn['key_0'].apply(lambda x: x[:5])
df_joined_nn.rename(columns={'key_0': 'code'}, inplace=True)
df_joined_nn = pd.merge(df_joined_nn, df_gloss, on='code')
# total_female_nn = df_female_nn.sum()[2]
# df_joined_nn['brand_femaleness'] = df_joined_nn['2_y'] / total_female_nn
# df_joined_nn

# %%
plt.clf()
rcParams['font.family'] = 'sans-serif'
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)
x_nn = []
y_nn = []
for index, row in df_joined_nn.iterrows():
    x_nn.append(row['category_femaleness'])
    y_nn.append(row['brand_femaleness'])
    plt.scatter(row['category_femaleness'], row['brand_femaleness'], c='black', s=1000, marker=r"$ {} $".format(row['code'][:5])) 
#plt.ylim(-0.01, 0.08)
plt.xlabel('Category Femaleness (%)')
plt.ylabel('Brand Femaleness (%)')
plt.title('Category Femaleness against Brand Femaleness from Glove Projections, Name-Like Brands Excluded')
plt.plot(x_nn, np.poly1d(np.polyfit(x_nn, y_nn, 1))(x_nn))
plt.savefig('glove_category_vs_brand_femaleness_no_names.png')
plt.show()

# %%
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x_nn, y_nn)
print("Slope: {:10.3f}\nIntercept: {:10.3f}\nR-value: {:10.3f}\nP-value: {:10.8f}\nStd-error: {:10.3f}".format(slope, intercept, r_value, p_value, std_err))
# Out:
# Slope:      0.462
# Intercept:      0.365
# R-value:      0.536
# P-value: 0.00000210
# Std-error:      0.089
